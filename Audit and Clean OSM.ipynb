# %%
import xml.etree.cElementTree as ET
import pprint
import re
from collections import defaultdict
from IPython.display import display
import operator
import codecs
import json

# %%
OSM_FILE = 'san-francisco-bay_california.osm'
#OSM_FILE = "sample-k-10.osm"
#OSM_FILE = "sample-k-100.osm"

street_type_re = re.compile(r'(\b\S+\.?)$', re.IGNORECASE) # "300 Bernal Ave." or "900 Cy Ranch Drive"
street_type_num_re = re.compile(r'(\b\S+\.?)(?= #?[0-9]+$)', re.IGNORECASE) # "20 Cal Avenue #32" or "15 Stevens Creek Hwy 2"

# %%
# Examples of using street_type_num_re
m = street_type_num_re.search("2030 Hwy 1")
print(m.group(1))

m = street_type_num_re.search("Old Bernal Ave #1")
print(m.group(1))

#m = street_type_num_re.search("Old Bernal Ave")
#print(m.group(1))
# Out:
# Hwy
# Ave

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# %%
def count_high_level_tags(filename):
    tags = defaultdict(int)
    
    #for i, elem in enumerate(get_element(OSM_FILE)):
    for event, elem in ET.iterparse(filename, events=('start', 'end')):
        tags[elem.tag] += 1
        
        # TODO(hkwik): I know I ought to clear the root, but not sure about elem.tag in tags.
        # Once I understand, I'll put this in.
        # if event == 'end' and elem.tag in tags: 
        #    root.clear()
    
    return tags

count_high_level_tags(OSM_FILE)
# Out:
# defaultdict(int,
#             {'bounds': 2,
#              'member': 199832,
#              'nd': 28718262,
#              'node': 24541624,
#              'osm': 2,
#              'relation': 22116,
#              'tag': 11056318,
#              'way': 2596034})

# %% [markdown]
# # Audit Keys

# %%
def count_keys(tag, keys):
    k = tag.attrib['k']
    keys[k] += 1
    pass

def audit_keys(osm_file):
    keys = defaultdict(int)
    for i, elem in enumerate(get_element(osm_file, tags=['node', 'way'])):
        for tag in elem.iter('tag'):
            count_keys(tag, keys)
    
    #osm_file.close()
    return keys

# %%
keys = audit_keys(OSM_FILE)

sorted_keys = sorted(keys.items(), key=operator.itemgetter(1))
sorted_keys[::-1]
# Out:
# [('building', 769773),
#  ('highway', 450609),
#  ('name', 298877),
#  ('addr:housenumber', 226713),
#  ('addr:street', 216430),
#  ('tiger:county', 208752),
#  ('tiger:cfcc', 198422),
#  ('addr:city', 185842),
#  ('tiger:name_base', 179842),
#  ('source', 172561),
#  ('tiger:name_type', 169963),
#  ('tiger:reviewed', 144771),
#  ('tiger:zip_left', 140678),
#  ('tiger:zip_right', 133904),
#  ('tiger:tlid', 95921),
#  ('tiger:source', 95492),
#  ('addr:state', 92623),
#  ('tiger:separated', 90630),
#  ('addr:postcode', 75539),
#  ('oneway', 69357),
#  ('height', 62744),
#  ('amenity', 51016),
#  ('service', 49919),
#  ('created_by', 45631),
#  ('lanes', 43212),
#  ('landuse', 38887),
#  ('waterway', 38661),
#  ('power', 30175),
#  ('maxspeed', 29213),
#  ('tiger:upload_uuid', 28703),
#  ('surface', 27185),
#  ('bicycle', 26295),
#  ('natural', 24853),
#  ('paloalto_ca:id', 24799),
#  ('leisure', 21511),
#  ('access', 19506),
#  ('ref', 18693),
#  ('redwood_city_ca:bld_gid', 18646),
#  ('nhd:reach_code', 17540),
#  ('cycleway', 17525),
#  ('foot', 17476),
#  ('layer', 17415),
#  ('redwood_city_ca:addr_id', 17130),
#  ('gnis:fcode', 17041),
#  ('nhd:fdate', 16991),
#  ('nhd:com_id', 16789),
#  ('addr:county', 15700),
#  ('turn:lanes', 14656),
#  ('boat', 14511),
#  ('scvwd:ROUTEID', 14256),
#  ('sidewalk', 14132),
#  ('railway', 13892),
#  ('gnis:ftype', 13836),
#  ('addr:country', 13713),
#  ('barrier', 13480),
#  ('ele', 13017),
#  ('attribution', 12598),
#  ('shop', 12289),
#  ('crossing', 12071),
#  ('gnis:feature_id', 11102),
#  ('tiger:name_base_1', 10849),
#  ('intermittent', 10231),
#  ('tiger:name_direction_prefix', 10023),
#  ('operator', 9675),
#  ('hgv', 9587),
#  ('gnis:created', 9432),
#  ('bridge', 9154),
#  ('gnis:county_id', 9100),
#  ('gnis:state_id', 9098),
#  ('description', 8327),
#  ('building:levels', 7311),
#  ('emergency', 7091),
#  ('website', 7017),
#  ('FMMP_modified', 6947),
#  ('FMMP_reviewed', 6870),
#  ('name_1', 6687),
#  ('sbc_apn', 6665),
#  ('sbc_parcel', 6665),
#  ('sbc_id', 6665),
#  ('sport', 6622),
#  ('source:maxspeed', 6333),
#  ('tiger:name_type_1', 5929),
#  ('cuisine', 5923),
#  ('generator:source', 5575),
#  ('hgv:national_network', 5474),
#  ('area', 5411),
#  ('phone', 5366),
#  ('man_made', 5344),
#  ('horse', 5252),
#  ('acres', 5084),
#  ('note:mk408', 5080),
#  ('source:hgv:national_network', 5025),
#  ('tunnel', 4918),
#  ('note', 4708),
#  ('massgis:cat', 4538),
#  ('tiger:zip_left_1', 4505),
#  ('footway', 4434),
#  ('tourism', 4374),
#  ('scvwd:FACILITY', 4229),
#  ('parking', 3969),
#  ('lanes:backward', 3885),
#  ('lanes:forward', 3865),
#  ('old_ref', 3821),
#  ('wheelchair', 3787),
#  ('turn:lanes:forward', 3689),
#  ('turn:lanes:backward', 3672),
#  ('cycleway:right', 3379),
#  ('leaf_type', 3115),
#  ('religion', 3057),
#  ('taxon', 2982),
#  ('motor_vehicle', 2941),
#  ('species:en', 2925),
#  ('gauge', 2865),
#  ('addr:full', 2673),
#  ('fields', 2608),
#  ('fields_ID', 2608),
#  ('len', 2605),
#  ('NO_SITE', 2605),
#  ('COMM_CODE', 2605),
#  ('NO_PRMT', 2605),
#  ('traffic_calming', 2585),
#  ('gnis:id', 2565),
#  ('NO_PRMT_SI', 2557),
#  ('opening_hours', 2508),
#  ('HFCS', 2507),
#  ('lcn_ref', 2395),
#  ('NHS', 2324),
#  ('crop', 2277),
#  ('lit', 2210),
#  ('electrified', 2208),
#  ('source:addr', 2165),
#  ('seasonal', 2115),
#  ('source:name', 1993),
#  ('place', 1906),
#  ('maxspeed:trailer', 1884),
#  ('public_transport', 1838),
#  ('maxspeed:hgv', 1826),
#  ('denomination', 1797),
#  ('entrance', 1785),
#  ('ID', 1784),
#  ('tiger:zip_right_1', 1779),
#  ('leaf_cycle', 1776),
#  ('capacity', 1770),
#  ('usage', 1756),
#  ('aeroway', 1754),
#  ('gnis:county_name', 1742),
#  ('golf', 1673),
#  ('shelter', 1651),
#  ('redwood_city_ca:bldg_id', 1612),
#  ('voltage', 1611),
#  ('SHAPE_len', 1556),
#  ('DT_ADD', 1535),
#  ('hgv:state_network', 1505),
#  ('source:hgv:state_network', 1495),
#  ('src:id', 1492),
#  ('is_in', 1471),
#  ('alt_name', 1441),
#  ('hov', 1418),
#  ('SHAPE_area', 1414),
#  ('gnis:import_uuid', 1363),
#  ('fee', 1358),
#  ('OPER_ADD', 1337),
#  ('note:lanes', 1320),
#  ('capture', 1317),
#  ('addr:paloaltoca_id', 1302),
#  ('DT_MANT', 1299),
#  ('destination', 1293),
#  ('noexit', 1274),
#  ('gnis:reviewed', 1227),
#  ('owner', 1198),
#  ('Tiger:MTFCC', 1172),
#  ('Shape_len', 1170),
#  ('Shape_area', 1169),
#  ('survey:date', 1164),
#  ('P_S_COMM', 1156),
#  ('PMT_SITE', 1156),
#  ('frequency', 1149),
#  ('tiger:zip_left_2', 1137),
#  ('route_ref', 1126),
#  ('COUNTYFP', 1125),
#  ('STATEFP', 1124),
#  ('office', 1122),
#  ('gnis:ST_alpha', 1110),
#  ('gnis:ST_num', 1110),
#  ('gnis:Class', 1107),
#  ('gnis:County', 1107),
#  ('gnis:County_num', 1106),
#  ('tracktype', 1102),
#  ('import_uuid', 1094),
#  ('exit_to', 1079),
#  ('trolley_wire', 1077),
#  ('direction', 1068),
#  ('OBJECTID', 1020),
#  ('GENERIC', 1010),
#  ('Zoning', 1009),
#  ('SHAPE_STLe', 1007),
#  ('SHAPE_STAr', 1004),
#  ('addr:unit', 998),
#  ('Zone', 973),
#  ('water', 966),
#  ('bus', 960),
#  ('covered', 924),
#  ('wikipedia', 918),
#  ('tiger:MTFCC', 916),
#  ('tiger:name_base_2', 914),
#  ('Atribution', 913),
#  ('cables', 911),
#  ('Attribution', 876),
#  ('bench', 824),
#  ('scvwd:COVERED', 809),
#  ('width', 800),
#  ('historic', 780),
#  ('old_name', 780),
#  ('MTFCC', 775),
#  ('ALAND', 761),
#  ('AWATER', 761),
#  ('FIXME', 723),
#  ('junction', 719),
#  ('latitude', 718),
#  ('longitude', 718),
#  ('level', 693),
#  ('network', 693),
#  ('source:geometry', 690),
#  ('wetland', 685),
#  ('addr:housename', 678),
#  ('OBJNAME', 669),
#  ('tiger:LINEARID', 662),
#  ('boundary', 645),
#  ('seamark:type', 644),
#  ('tiger:name_direction_suffix', 634),
#  ('AREAID', 630),
#  ('smoking', 628),
#  ('smoothness', 627),
#  ('ticker', 620),
#  ('landcover', 608),
#  ('length', 604),
#  ('traffic_signals:direction', 602),
#  ('wires', 577),
#  ('rwc_ca:buildingid', 555),
#  ('dog', 543),
#  ('lcn', 527),
#  ('contact:phone', 526),
#  ('motorcycle', 522),
#  ('atm', 514),
#  ('addr:interpolation', 507),
#  ('tiger:name_direction_prefix_1', 507),
#  ('information', 503),
#  ('mrosd:preserve', 493),
#  ('fixme', 492),
#  ('building:material', 487),
#  ('name:en', 481),
#  ('tiger:RTTYP', 479),
#  ('internet_access', 470),
#  ('sac_scale', 467),
#  ('tiger:zip_right_2', 459),
#  ('takeaway', 459),
#  ('mrosd:version', 457),
#  ('brand', 456),
#  ('placement', 428),
#  ('contact:website', 425),
#  ('bicycle_parking', 419),
#  ('BLDGID', 419),
#  ('tiger:mtfcc', 416),
#  ('type', 413),
#  ('motorcar', 409),
#  ('vta:id', 408),
#  ('incline', 404),
#  ('admin_level', 402),
#  ('destination:ref', 396),
#  ('AREA_M2', 395),
#  ('outdoor_seating', 388),
#  ('park:type', 375),
#  ('utility_wires', 370),
#  ('backrest', 367),
#  ('addr:flats', 366),
#  ('overtaking', 357),
#  ('gnis:feature_type', 346),
#  ('generator:method', 336),
#  ('designation', 334),
#  ('material', 330),
#  ('construction', 327),
#  ('tiger:zip_left_3', 325),
#  ('gnis:edited', 320),
#  ('segregated', 318),
#  ('unsigned_ref', 317),
#  ('source_ref', 316),
#  ('traffic_signals:sound', 309),
#  ('traffic_signals', 309),
#  ('craft', 308),
#  ('location', 307),
#  ('old_railway_operator', 303),
#  ('source:pkey', 297),
#  ('email', 295),
#  ('abutters', 293),
#  ('capacity:disabled', 293),
#  ('bulb', 292),
#  ('OPER_MANT', 291),
#  ('border_type', 284),
#  ('history', 280),
#  ('button_operated', 275),
#  ('fire_hydrant:type', 273),
#  ('turn:lanes:both_ways', 270),
#  ('drive_through', 269),
#  ('fence_type', 268),
#  ('turn_restrictions', 266),
#  ('sfgov:OBJNAME', 265),
#  ('tiger:STATEFP', 258),
#  ('toilets:disposal', 253),
#  ('toll', 251),
#  ('is_in:country', 248),
#  ('tiger:FUNCSTAT', 247),
#  ('tiger:PLACEFP', 247),
#  ('tiger:NAME', 247),
#  ('tiger:CPI', 247),
#  ('tiger:PCICBSA', 247),
#  ('tiger:PLCIDFP', 247),
#  ('tiger:PLACENS', 247),
#  ('tiger:CLASSFP', 247),
#  ('tiger:PCINECTA', 247),
#  ('tiger:LSAD', 247),
#  ('tiger:NAMELSAD', 247),
#  ('name:zh', 245),
#  ('animal', 243),
#  ('traffic_sign', 242),
#  ('is_in:state', 241),
#  ('tiger:name_type_2', 239),
#  ('url', 238),
#  ('pipe_type', 236),
#  ('lanes:both_ways', 235),
#  ('park_ride', 234),
#  ('denotation', 232),
#  ('irrigated', 232),
#  ('is_in:country_code', 230),
#  ('tower:type', 228),
#  ('house', 228),
#  ('quantity', 228),
#  ('name_2', 224),
#  ('nps:trail', 224),
#  ('importuuid', 224),
#  ('nps:pets', 224),
#  ('change:lanes', 223),
#  ('is_in:iso_3166_2', 218),
#  ('elev', 218),
#  ('is_in:state_code', 217),
#  ('size', 213),
#  ('nps:length', 212),
#  ('fax', 212),
#  ('destination:street', 209),
#  ('payment:bitcoin', 202),
#  ('route', 201),
#  ('maxweight', 201),
#  ('roof:shape', 192),
#  ('addr:1:housenumber', 189),
#  ('placement:backward', 186),
#  ('rwc_ca:id', 180),
#  ('nps:condition', 180),
#  ('fire_hydrant:position', 178),
#  ('nps:type', 177),
#  ('delivery', 173),
#  ('cycleway:left', 171),
#  ('caltrans:district', 169),
#  ('railway:traffic_mode', 169),
#  ('building:part', 169),
#  ('tactile_paving', 168),
#  ('floating', 166),
#  ('supervised', 163),
#  ('tiger:name_base_3', 162),
#  ('wikidata', 160),
#  ('wetap:status', 159),
#  ('trees', 157),
#  ('change:lanes:backward', 156),
#  ('power_source', 156),
#  ('building:condition', 154),
#  ('occurrence', 154),
#  ('trail_visibility', 154),
#  ('tower:construction', 153),
#  ('addr:side', 152),
#  ('drinking_water', 152),
#  ('population', 151),
#  ('seamark:name', 149),
#  ('Tiger:HYDROID', 148),
#  ('gns:id', 145),
#  ('start_date', 145),
#  ('tiger:name_full', 143),
#  ('change:lanes:forward', 142),
#  ('path_type', 141),
#  ('FIXME:bicycle', 140),
#  ('hov:lanes', 139),
#  ('seamark:beacon_lateral:category', 138),
#  ('seamark:beacon_lateral:colour', 138),
#  ('facility', 138),
#  ('unisex', 137),
#  ('placement:forward', 137),
#  ('lane', 136),
#  ('recycling_type', 133),
#  ('seamark:light:character', 132),
#  ('built', 132),
#  ('NR_STATUS', 132),
#  ('BRIDGE_NO', 132),
#  ('status', 131),
#  ('postmile', 131),
#  ('seamark:beacon_lateral:shape', 130),
#  ('seamark:light:colour', 130),
#  ('toilets', 129),
#  ('road_marking', 129),
#  ('sloped_curb', 128),
#  ('seamark:light:period', 125),
#  ('seamark:status', 125),
#  ('subway', 124),
#  ('kerb', 123),
#  ('wifi', 122),
#  ('tiger:name_direction_suffix_1', 122),
#  ('Trunk_Diam', 120),
#  ('Subclass', 117),
#  ('common', 117),
#  ('csp:globalid', 117),
#  ('csp:unitcode', 117),
#  ('name:es', 116),
#  ('tiger:zip_right_3', 115),
#  ('dispensing', 115),
#  ('land_type', 115),
#  ('short_name', 113),
#  ('psv', 113),
#  ('recommended_speed', 112),
#  ('census:population', 112),
#  ('est_width', 109),
#  ('ford', 107),
#  ('board_type', 107),
#  ('stop', 107),
#  ('microbrewery', 106),
#  ('species', 106),
#  ('proposed', 106),
#  ('camp_site', 104),
#  ('seamark:rock:water_level', 103),
#  ('vending', 102),
#  ('tiger:zip_left_4', 100),
#  ('noaa:taghash', 99),
#  ('noaa:geohash', 99),
#  ('noaa:lnam', 99),
#  ('id', 99),
#  ('change:forward', 98),
#  ('destination:lanes', 98),
#  ('scvwd:AREA_FT', 98),
#  ('odbl', 98),
#  ('scvwd:POND_NUM', 98),
#  ('scvwd:AREA_AC', 97),
#  ('seamark:rock:quality', 96),
#  ('disused', 96),
#  ('name:vi', 96),
#  ('outside', 95),
#  ('payment:litecoin', 94),
#  ('hgv:minweight', 93),
#  ('maxspeed:towing', 92),
#  ('scvwd:SHAPE_Area', 92),
#  ('scvwd:OBJECTID', 91),
#  ('colour', 90),
#  ('caltrans:type', 90),
#  ('cutting', 89),
#  ('hoops', 89),
#  ('maxspeed:advisory', 88),
#  ('caltrans:dynsegpm', 88),
#  ('name:absent', 87),
#  ('bottle', 86),
#  ('local_ref', 85),
#  ('change:backward', 85),
#  ('roof:levels', 84),
#  ('artwork_type', 82),
#  ('seamark:light:sequence', 82),
#  ('attraction', 81),
#  ('loc_name', 81),
#  ('noref', 81),
#  ('maxheight', 80),
#  ('drive_in', 80),
#  ('verified:name', 80),
#  ('addr:2:housenumber', 80),
#  ('scvwd:GIS_ID', 78),
#  ('scvwd:SYS_NAME', 78),
#  ('scvwd:OWNER', 78),
#  ('source:website', 77),
#  ('monitoring:water_level', 76),
#  ('parking:lane:both', 76),
#  ('seamark:light:exhibition', 75),
#  ('seamark:light:range', 75),
#  ('addr.source:housenumber', 75),
#  ('toilets:position', 74),
#  ('FMMP_land_type', 73),
#  ('caltrans:pctuse', 72),
#  ('seamark:light:height', 72),
#  ('lot_no', 72),
#  ('train', 71),
#  ('seamark:daymark:shape', 70),
#  ('todo', 70),
#  ('seamark:daymark:colour', 70),
#  ('seamark:daymark:colour_pattern', 70),
#  ('mtb:scale', 69),
#  ('scvwd:MAXIMO_ID', 69),
#  ('address', 68),
#  ('step_count', 68),
#  ('toilets:wheelchair', 68),
#  ('embankment', 67),
#  ('hiking', 65),
#  ('minweight:hgv', 65),
#  ('dogs', 65),
#  ('ANSICODE', 64),
#  ('camp_pitch:parking', 64),
#  ('camp_pitch:type', 64),
#  ('camp_pitch:picnic_table', 64),
#  ('camp_pitch:fire', 64),
#  ('camp_pitch:drain', 64),
#  ('camp_pitch:drinking_water', 64),
#  ('roof:colour', 64),
#  ('camp_pitch:electric', 64),
#  ('parking:condition:both', 62),
#  ('crossing_ref', 62),
#  ('internet_access:fee', 62),
#  ('indoor', 61),
#  ('scvwd:NAME', 61),
#  ('wetap:photo', 61),
#  ('turn', 61),
#  ('recycling:cans', 60),
#  ('roof:height', 60),
#  ('playground', 58),
#  ('recycling:plastic_bottles', 58),
#  ('disused:amenity', 57),
#  ('collection_times', 57),
#  ('stop_id', 56),
#  ('motor_vehicle:lanes', 56),
#  ('mrosd:name_2', 56),
#  ('amenity:historic', 55),
#  ('comment', 54),
#  ('cable_car', 54),
#  ('historic:name', 52),
#  ('tomb', 51),
#  ('destination:ref:lanes', 51),
#  ('seamark:buoy_lateral:colour', 51),
#  ('seamark:buoy_lateral:shape', 51),
#  ('seamark:buoy_lateral:category', 51),
#  ('male', 50),
#  ('service:bicycle:pump', 50),
#  ('informal', 49),
#  ('mincyclewidth', 49),
#  ('scvwd:SHAPE_AREA', 49),
#  ('open_date', 49),
#  ('mooring', 48),
#  ('tiger:arid', 48),
#  ('addr:inclusion', 48),
#  ('seamark:daymark:construction', 47),
#  ('fuel', 47),
#  ('maxcyclewidth', 47),
#  ('social_facility:for', 47),
#  ('scvwd:WB_TYPE', 46),
#  ('capacity:motorcycle', 45),
#  ('capacity:bike_locke', 45),
#  ('capacity:kiss_n_rid', 45),
#  ('capacity:bike_rack', 45),
#  ('vta:owner', 45),
#  ('capacity:compact', 45),
#  ('cooperative', 45),
#  ('capacity:loading_zn', 45),
#  ('capacity:disabled_v', 45),
#  ('female', 44),
#  ('capacity:standard', 44),
#  ('public', 44),
#  ('addr:3:housenumber', 43),
#  ('outside_atm', 42),
#  ('protect_class', 42),
#  ('crossing:bell', 42),
#  ('avgspeed', 42),
#  ('military', 42),
#  ('tiger:zip_right_4', 40),
#  ('destination:backward', 40),
#  ('ref:left', 40),
#  ('artist_name', 40),
#  ('exit_to:left', 40),
#  ('healthcare', 39),
#  ('seamark:fog_signal:category', 39),
#  ('ref:right', 39),
#  ('county', 39),
#  ('generator:type', 38),
#  ('vehicle', 38),
#  ('sym', 37),
#  ('destination:forward', 37),
#  ('healthcare:speciality', 37),
#  ('zoo', 36),
#  ('cmt', 36),
#  ('generator:output:electricity', 35),
#  ('social_facility', 35),
#  ('crossing:light', 35),
#  ('destination:lanes:backward', 35),
#  ('contact:email', 35),
#  ('bicycle:lanes', 35),
#  ('sfgov.org:OFFICE_TYP', 35),
#  ('tiger:name_direction_prefix_2', 35),
#  ('sfgov.org:OBJECTID', 35),
#  ('exit_to:right', 35),
#  ('addr:place', 35),
#  ('seamark:beacon_special_purpose:shape', 34),
#  ('hazmat', 34),
#  ('note:hgv', 34),
#  ('service:bicycle:repair', 34),
#  ('wetap:statusnote', 33),
#  ('wetap:quality', 33),
#  ('operator:type', 33),
#  ('tiger:ALAND', 32),
#  ('roof:slope:direction', 32),
#  ('service:bicycle:retail', 32),
#  ('tiger:AREAID', 32),
#  ('tiger:AWATER', 32),
#  ('protection_title', 32),
#  ('ref:blklot', 32),
#  ('gosm:sig:8CBDE645', 32),
#  ('busway', 32),
#  ('tiger:COUNTYFP', 32),
#  ('name:ko', 31),
#  ('roof:material', 31),
#  ('recycling:cardboard', 31),
#  ('notes3', 31),
#  ('organic', 30),
#  ('bridge:ref', 30),
#  ('wetap:flow', 30),
#  ('map_size', 30),
#  ('telecom', 30),
#  ('service:bicycle:chain_tool', 30),
#  ('wetap:temperature', 30),
#  ('recycling:paper', 30),
#  ('note:address', 29),
#  ('recycling:glass_bottles', 29),
#  ('destination:ref:backward', 29),
#  ('destination:ref:lanes:forward', 29),
#  ('seamark', 29),
#  ('grade', 29),
#  ('fireplace', 29),
#  ('parking:condition:right:2:time_interval', 28),
#  ('architect', 28),
#  ('second_hand', 28),
#  ('parking:condition:right:2', 28),
#  ('parking:condition:left:2', 28),
#  ('parking:condition:left:2:time_interval', 28),
#  ('depository', 28),
#  ('parking:condition:right:2:reason', 28),
#  ('addr:4:housenumber', 28),
#  ('parking:condition:left:2:reason', 28),
#  ('golf_cart', 27),
#  ('maxlength', 27),
#  ('nps:comment', 27),
#  ('camp_site:table', 27),
#  ('destination:ref:forward', 27),
#  ('par', 27),
#  ('maxwidth', 27),
#  ('camp_site:fire', 27),
#  ('note:highway', 27),
#  ('camp_site:type', 27),
#  ('passenger', 27),
#  ('Id', 26),
#  ('seamark:reference', 26),
#  ('destination:lanes:forward', 26),
#  ('maxstay', 26),
#  ('rwc_ca:address_id', 26),
#  ('place_name', 26),
#  ('addr:5:housenumber', 25),
#  ('wpt_description', 25),
#  ('payment:cash', 25),
#  ('payment:visa', 25),
#  ('bridge:structure', 25),
#  ('courts', 24),
#  ('seamark:buoy_lateral:system', 24),
#  ('name:ru', 24),
#  ('name:ar', 24),
#  ('FIXME:hgv', 24),
#  ('shelter_type', 24),
#  ('difficulty', 24),
#  ('hist_name', 24),
#  ('image', 24),
#  ('official_name', 24),
#  ('fuel:diesel', 24),
#  ('seamark:beacon_special_purpose:colour', 24),
#  ('noname', 23),
#  ('source_import', 23),
#  ('center_turn_lane', 23),
#  ('icao', 23),
#  ('separated', 23),
#  ('generator:place', 22),
#  ('payment:american_express', 22),
#  ('shop:historic', 22),
#  ('payment:mastercard', 22),
#  ('addr:floor', 22),
#  ('handrail', 22),
#  ('clothes', 22),
#  ('buoy', 21),
#  ('source:opening_hours', 21),
#  ('passenger_lines', 21),
#  ('bin', 21),
#  ('residential', 21),
#  ('min_height', 21),
#  ('bridge:name', 21),
#  ('sanitary_dump_station', 21),
#  ('grades', 21),
#  ('iata', 21),
#  ('ski', 20),
#  ('station_name', 20),
#  ('is_in:county', 20),
#  ('camp_site:surface', 20),
#  ('crossing:barrier', 20),
#  ('heritage', 20),
#  ('camp_site:parking', 20),
#  ('access:bicycle', 20),
#  ('payment:discover_card', 20),
#  ('culvert', 20),
#  ('contact:fax', 20),
#  ('disused:shop', 20),
#  ('camp_site:drain', 20),
#  ('map_type', 20),
#  ('camp_site:electric', 20),
#  ('camp_site:water', 20),
#  ('diet:vegetarian', 20),
#  ('addr:6:housenumber', 20),
#  ('payment:coins', 20),
#  ('is_in:continent', 20),
#  ('rcn', 19),
#  ('control', 19),
#  ('snowmobile', 19),
#  ('seamark:beacon_special_purpose:category', 19),
#  ('fuel:octane_91', 19),
#  ('surveillance', 19),
#  ('horses', 19),
#  ('nist:fips_code', 19),
#  ('baby_hatch', 19),
#  ('dry_clean', 19),
#  ('closest_town', 19),
#  ('self_service', 19),
#  ('ramp', 18),
#  ('buoy:colour', 18),
#  ('seamark:buoy_special_purpose:colour', 18),
#  ('faa', 18),
#  ('stars', 18),
#  ('name:de', 18),
#  ('taxi', 18),
#  ('railway:preserved', 18),
#  ('handicap', 18),
#  ('destination:ref:lanes:backward', 18),
#  ('inner', 18),
#  ('bicycle:lanes:backward', 18),
#  ('boundary_type', 17),
#  ('surveillance:type', 17),
#  ('health_speciality', 17),
#  ('stateofrepair', 17),
#  ('oneway:bicycle', 17),
#  ('seamark:buoy_special_purpose:shape', 17),
#  ('seamark:fog_signal:period', 17),
#  ('wheelchair:description', 17),
#  ('mtb:scale:uphill', 17),
#  ('name:ja', 17),
#  ('bicycle:lanes:forward', 17),
#  ('state', 16),
#  ('service:bicycle:diy', 16),
#  ('tram', 16),
#  ('vehicle:lanes', 16),
#  ('substation', 16),
#  ('mtb:scale:imba', 16),
#  ('seamark:information', 16),
#  ('recycling:aluminium', 16),
#  ('lanes:source', 16),
#  ('nudism', 16),
#  ('verified', 16),
#  ('CertStat', 16),
#  ('CertID', 16),
#  ('ramp:wheelchair', 16),
#  ('sign', 16),
#  ('alterations', 16),
#  ('seamark:light:reference', 16),
#  ('addr:suite', 16),
#  ('recycling:glass', 16),
#  ('path', 16),
#  ('disused:name', 15),
#  ('source:phone', 15),
#  ('seats', 15),
#  ('building:levels:underground', 15),
#  ('food', 15),
#  ('source:outline', 15),
#  ('content', 15),
#  ('access:foot', 15),
#  ('voltage-high', 15),
#  ('parking:condition:both:maxstay', 14),
#  ('light', 14),
#  ('Open_Date', 14),
#  ('source:date', 14),
#  ('parking:condition:both:residents', 14),
#  ('parking:condition:both:time_interval', 14),
#  ('boundary:type', 14),
#  ('mrosd:point_of_interest', 14),
#  ('proposed:railway', 14),
#  ('enterance', 14),
#  ('training', 14),
#  ('payment:diners_club', 14),
#  ('car', 14),
#  ('railway:proposed', 14),
#  ('seamark:fog_signal:group', 14),
#  ('turn:backward', 14),
#  ('coin_op', 14),
#  ('security_zone', 13),
#  ('source_1', 13),
#  ('finished_laundry', 13),
#  ('mown', 13),
#  ('is_in:city', 13),
#  ('building:colour', 13),
#  ('levels', 13),
#  ('source:lit', 13),
#  ('barbecue_grill', 13),
#  ('name_3', 13),
#  ('access:conditional', 13),
#  ('addr_house', 13),
#  ('turn:forward', 13),
#  ('island', 13),
#  ('seamark:beacon_lateral:reflectivity', 13),
#  ('abandoned', 13),
#  ('wetap:credit', 13),
#  ('website:official', 13),
#  ('historical:name', 13),
#  ('golf:course', 13),
#  ('inscription', 13),
#  ('ship:type', 13),
#  ('lastcheck:status', 13),
#  ('access:lanes', 13),
#  ('jams', 12),
#  ('socket:chademo', 12),
#  ('service:bicycle:rental', 12),
#  ('source:maxspeed:backward', 12),
#  ('abandoned:highway', 12),
#  ('recycling:newspaper', 12),
#  ('fuel:octane_87', 12),
#  ('building:use', 12),
#  ('trade', 12),
#  ('seamark:light:group', 12),
#  ('tailgaiting', 12),
#  ('shoulder', 12),
#  ('memorial', 12),
#  ('historic:amenity', 12),
#  ('note_2', 11),
#  ('bearing', 11),
#  ('terminal', 11),
#  ('NRHP', 11),
#  ('manhole', 11),
#  ('parking_meters', 11),
#  ('hazard', 11),
#  ('visibility', 11),
#  ('socket:type1', 11),
#  ('building:min_level', 11),
#  ('health_specialty', 11),
#  ('seamark:fog_signal:generation', 11),
#  ('outside_atm_operator', 11),
#  ('amenity_1', 11),
#  ('lcr', 11),
#  ('ref:nrhp', 11),
#  ('telescope:type', 11),
#  ('addr:7:housenumber', 11),
#  ('bus:lanes', 11),
#  ('flag:type', 11),
#  ('ref:nhrp', 11),
#  ('tiger:name_direction_suffix_2', 11),
#  ('name_alt', 11),
#  ('postal_code', 11),
#  ('street', 11),
#  ('rooms', 10),
#  ('lastcheck:note', 10),
#  ('seamark:topmark:shape', 10),
#  ('junction:ref', 10),
#  ('source:destination', 10),
#  ('lines', 10),
#  ('fut_ref', 10),
#  ('tiger:name_type_3', 10),
#  ('flashing_lights', 10),
#  ('seamark:fog_signal:sequence', 10),
#  ('brand:wikidata', 10),
#  ('Acres', 10),
#  ('condition', 10),
#  ('hour_on', 10),
#  ('TODO', 10),
#  ('parking:restricted', 10),
#  ('diet:vegan', 10),
#  ('outside_atm_capacity', 10),
#  ('club', 10),
#  ('seamark:topmark:colour', 10),
#  ('car_wash', 10),
#  ('recycling:plastic', 10),
#  ('hour_off', 10),
#  ('vestibule_atm', 10),
#  ('genus', 10),
#  ('contents', 10),
#  ('voltage-low', 9),
#  ('recycling:cartons', 9),
#  ('payment:none', 9),
#  ('payment:credit_cards', 9),
#  ('FG:ORG_CODE', 9),
#  ('dist:red', 9),
#  ('emergency_service', 9),
#  ('recycling:clothes', 9),
#  ('private', 9),
#  ('payment:dogecoin', 9),
#  ('recycling:magazines', 9),
#  ('suite', 9),
#  ('sanitary_dump_station:pump-out', 9),
#  ('recycling:paper_packaging', 9),
#  ('x_coordinate', 9),
#  ('psv:lanes', 9),
#  ('vehicle:conditional', 9),
#  ('gnis:state', 9),
#  ('ntd_id', 9),
#  ('FG:RTE', 9),
#  ('FG:photo', 9),
#  ('dist:blue', 9),
#  ('FG:area', 9),
#  ('FG:GPS_DATE', 9),
#  ('prop_description', 9),
#  ('end_date', 9),
#  ('building:height', 9),
#  ('area:highway', 9),
#  ('FG:perimeter', 9),
#  ('recycling:plastic_packaging', 9),
#  ('drinking_water:bottle', 9),
#  ('FG:lane_miles', 9),
#  ('power_supply', 9),
#  ('y_coordinate', 9),
#  ('rating', 9),
#  ('FG:COND_INDEX', 9),
#  ('lanes:bus', 9),
#  ('disused:highway', 9),
#  ('FG:station', 9),
#  ('fuel:lpg', 9),
#  ('gtfs_id', 9),
#  ('FG:route', 9),
#  ('diaper', 9),
#  ('lastcheck:date', 9),
#  ('FG:rte_description', 9),
#  ('dist:white', 9),
#  ('FG:visitors', 9),
#  ('taxiway', 9),
#  ('name:pt', 9),
#  ('inside_atm', 9),
#  ('heritage:operator', 8),
#  ('books', 8),
#  ('automated', 8),
#  ('site', 8),
#  ('_Shape_Leng_', 8),
#  ('_Shape_Area_', 8),
#  ('recycling:compost', 8),
#  ('kiosk', 8),
#  ('outerspatial:id', 8),
#  ('user_defined_other', 8),
#  ('old_tourism', 8),
#  ('est_height', 8),
#  ('dry_weather_only', 8),
#  ('FIXME:name', 8),
#  ('beacon', 8),
#  ('seamark:beacon_safe_water:shape', 8),
#  ('service:bicycle:second_hand', 8),
#  ('wood', 8),
#  ('samtrans_route_ref', 8),
#  ('telescope:diameter', 8),
#  ('tidal', 8),
#  ('field_marking', 8),
#  ('mtb', 8),
#  ('_Acres_', 8),
#  ('elevator', 8),
#  ('bus:lanes:backward', 8),
#  ('restriction', 8),
#  ('change:both_ways', 8),
#  ('name:fr', 8),
#  ('substance', 8),
#  ('school', 8),
#  ('health_facility:type', 8),
#  ('old_name:vi', 7),
#  ('platforms', 7),
#  ('seamark:landmark:category', 7),
#  ('fuel:cng', 7),
#  ('notes', 7),
#  ('repair', 7),
#  ('vestibule_atm_capacity', 7),
#  ('name:ca', 7),
#  ('ethnicity', 7),
#  ('Shape_Area', 7),
#  ('lastcheck', 7),
#  ('FIXME:old_ref', 7),
#  ('source:position', 7),
#  ('name:uk', 7),
#  ('cost:coffee', 7),
#  ('ggt_route_ref', 7),
#  ('restrooms', 7),
#  ('parking:lane:right', 7),
#  ('climbing', 7),
#  ('circumference', 7),
#  ('taqueria', 7),
#  ('int_name', 7),
#  ('traction', 7),
#  ('name:it', 7),
#  ('change:lanes:both_ways', 7),
#  ('topmark', 7),
#  ('steps', 7),
#  ('parking:lane:left', 7),
#  ('country', 7),
#  ('drinkwater', 7),
#  ...]

# %% [markdown]
# # Audit Addresses

# %%
expected = ["Alley", "Avenue", "Boulevard", "Center", "Circle", "Common", "Commons", 
            "Corte", "Court", "Courtyard", "Drive", "Expressway", 
            "Highway", "Lane", "Loop", "Mall", "Path", "Park", "Parkway", "Place", "Plaza",
            "Real", "Road", "Square", "Street", "Terrace", "Trail", "Walk",
            "Way"]

mapping = { "Aly": "Alley",
            "avenue": "Avenue",
            "AVE": "Avenue",
            "Ave": "Avenue",
            "Aveenue": "Avenue",
            "Avenie": "Avenue",
            "Ave.": "Avenue",
            "blvd": "Boulevard",
            "BLVD.": "Boulevard",
            "BLVD": "Boulevard",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Boulvevard": "Boulevard",
            "Boulevar": "Boulevard",
            "Cir": "Circle",
            "Circle:": "Circle",
            "court": "Court",
            "Ct": "Court",
            "Ct.": "Court",
            "Ctr": "Center",
            "Dr": "Drive",
            "Dr.": "Drive",
            "Expwy": "Expressway",
            "Hwy": "Highway",
            "Hwy.": "Highway",
            "Ln": "Lane",
            "Ln.": "Lane",
            "parkway": "Parkway",
            "PKWY": "Parkway",
            "PL": "Place",
            "Pl": "Place",
            "PT": "Point",
            "road": "Road",
            "Rd": "Road",
            "Rd.": "Road",
            "st": "Street",
            "St": "Street",
            "St.": "Street",
            "street": "Street",
            "terrace": "Terrace",
            "way": "Way",
            "WAy": "Way"
            }

# %%
def audit_street_type_regex(street_types, regex, street_name):
    # Assume group(1) contains the street type
    m = regex.search(street_name)
    if m:
        street_type = m.group(1)
        if street_type not in expected and street_type not in mapping:
            street_types[street_type].add(street_name)

def audit_street_type(street_types, street_name):
    audit_street_type_regex(street_types, street_type_re, street_name)
    audit_street_type_regex(street_types, street_type_num_re, street_name)
    
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def is_postcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def is_county(elem):
    return (elem.attrib['k'] == "addr:county")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    postcodes = defaultdict(int)
    counties = defaultdict(int)
    
    for i, elem in enumerate(get_element(osm_file)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                k = tag.attrib['k']
                v = tag.attrib['v']
                
                if is_street_name(tag):
                    audit_street_type(street_types, v)
                
                if is_postcode(tag):
                    postcodes[v] += 1
                    
                if is_county(tag):
                    counties[v] += 1
                    
    osm_file.close()
    return street_types, postcodes, counties


def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        new_street_type = mapping[street_type]
        name = re.sub(street_type_re, new_street_type, name)
    return name

# %%
street_types, post_codes, counties = audit(OSM_FILE)

# %%
street_types
# Out:
# defaultdict(set,
#             {'0.1': {'Ala 680 PM 0.1'},
#              '1': {'10795 Hwy 1',
#               '2030 Hwy 1',
#               'California Highway 16, House No. 1',
#               'Old Bernal Ave #1',
#               'Prospect Rd #1',
#               'State Hwy 1',
#               'Stewart Drive Suite #1',
#               'W Of Us 101 @ Jct Sr 1'},
#              '10': {'San Mateo 35 PM 10', 'South St #10'},
#              '100': {'Northgate Blvd #100', 'Woodside Road, Suite 100'},
#              '101': {'Highway 101',
#               'Nw Quad Lincoln Ave / Us 101',
#               'Se Quad Smith Ranch Rd / Us 101'},
#              '102': {'County Road 102'},
#              '105': {'N California Blvd #105'},
#              '10675': {'10675'},
#              '11': {'Fairview Rd #11'},
#              '110': {'West Angela Street, Suite 110'},
#              '110,': {'Promenade Circle #110,'},
#              '114': {'West Evelyn Avenue Suite #114'},
#              '116': {'Hwy 116',
#               'In "Y" Jct Of Sr 121 / Sr 116',
#               'W Side Of Us 101 @ Sr 116'},
#              '12': {'480 Highway 12',
#               'Hawkins St #12',
#               'Main Street At Sr 12',
#               'Rustic St #12'},
#              '120': {'E. Hwy 120', 'East Highway 120'},
#              '12180142': {'12180142'},
#              u'122\xb029\'07.1"W': {u'37\xb042\'46.0"N 122\xb029\'07.1"W'},
#              '128': {'Highway 128', 'State Highway 128'},
#              '13': {'North Port Rd 13'},
#              '140': {'West Highway 140'},
#              '15': {'Doolittle Dr, Suite 15'},
#              '155': {'University Ave #155', 'Woodside Road, Suite 155'},
#              '15th': {'15th'},
#              '16360': {'16360'},
#              '165': {'Las Positas Ct #165'},
#              '18C': {'County Road 18C'},
#              '1st': {'Thomas Lane Off 1st'},
#              '2': {'College St #2',
#               'Port Rd 2',
#               'San Francisco Bicycle Route 2',
#               'San Ramon Valley Blvd #2',
#               'Showers Drive STE 2'},
#              '2.0': {'Hwy 780 PM 2.0'},
#              '200': {'Clay St # 200', 'Watt Ave #200'},
#              '201': {'Great America Pkwy Ste 201'},
#              '203': {'Bartlett Street #203'},
#              '213': {'West Las Positas Boulevard #213'},
#              '22': {'Port Rd 22'},
#              '23': {'Port Rd 23', 'Via Padre #23'},
#              '245': {'245'},
#              '25': {'Via Padre #25'},
#              '26': {'East State Route 26'},
#              '27': {'Via Padre #27'},
#              '29': {'Fairview Rd #29', 'Via Padre #29'},
#              '3': {'University Dr. Suite 3'},
#              '3.2': {'ALA 84 PM 3.2'},
#              '302': {'Mission Blvd #302'},
#              '31': {'Via Padre #31'},
#              '310': {'Greenback Lane, Suite 310'},
#              '32': {'Carpenter Rd #32'},
#              '330': {'2nd St Suite 330'},
#              '3500': {'Sansome St #3500'},
#              '352': {'Elmira Rd #352'},
#              '3658': {'Market Street Suite 3658'},
#              '39': {'Pier 39'},
#              '4': {'4',
#               'East State Route 4',
#               'Menlo Ave  # 4',
#               'Pacheco Blvd @ Blum Rd N Of Sr 4',
#               'State Highway 4',
#               'West State Route 4'},
#              '4.5': {'SF 80 PM 4.5'},
#              '400': {'E Bidwell St #400'},
#              '402A': {'Fair Oaks Blvd #402A'},
#              '404': {'16th St #404'},
#              '41276': {'Upton St 41276'},
#              '43.6': {'Hwy 29 PM 43.6'},
#              '438': {'South St #438'},
#              '4A': {'Saratoga Avenue Bldg 4A'},
#              '5': {'2nd St/Rte 5', 'Industrial Pl #5'},
#              '50': {'3rd St / Rte 50'},
#              '5259': {'PO Box 5259'},
#              '56': {'Fairview Road Sp 56'},
#              '6': {'Martin Avenue #6'},
#              '63': {'Fairview Rd #63'},
#              '7': {'Showers Drive STE 7'},
#              '7.1': {'Hwy 17 PM 7.1'},
#              '7193': {'7193'},
#              '730': {'Sansome Street Ste 730', 'Sansome Street Suite 730'},
#              '803': {'Line St #803'},
#              '81': {'Concourse Dr #81'},
#              '88': {'East State Route 88', 'N HWY 88', 'North Highway 88'},
#              '9': {'East Charleston Road APT 9',
#               'Highway 9',
#               'Hwy 9',
#               'Hwy. 9'},
#              '94B': {'County Road 94B'},
#              '95': {'Sally St #95'},
#              '95628-7416': {'Fair Oaks Boulevard, Fair Oaks, CA 95628-7416'},
#              '95683': {'Pera Dr at Escuela Drive, Rancho Murieta, Ca 95683'},
#              '98': {'County Road 98'},
#              '99': {'13th Ave Rte 99',
#               '47th Avenue / Rte 99',
#               'County Road 99'},
#              'A': {'Adrian Court, Suite A',
#               'First Street, Suite A',
#               'Lane A',
#               'N W Ln #A',
#               'Pier 50 A',
#               'Upton St #A'},
#              'AA': {'Showers Drive BLDG AA'},
#              'AL': {'Bieghle AL'},
#              'APT': {'East Charleston Road APT 9'},
#              'Airport': {'San Francisco Internation Airport'},
#              'Alameda': {'Alameda', 'The Alameda'},
#              'Alemeda': {'The Alemeda'},
#              'Alto': {'Camino Alto'},
#              'Antonio': {'Calle San Antonio'},
#              'Arena': {'Arena'},
#              'Arguello': {'Arguello'},
#              'Arroyo': {'Camino Arroyo'},
#              'Ashfield': {'Ashfield'},
#              'Auburn': {'Auburn'},
#              'Axis': {'North-South Axis'},
#              'B': {'Avenue B', 'Leghorn Street #B', 'Pier 50 B', 'Utah St #B'},
#              'Barcelona': {'Calle de Barcelona'},
#              'Bascom': {'S. Bascom'},
#              'Bay': {'Bay'},
#              'Bellomy': {'Bellomy'},
#              'Bikeway': {'Sprockett Bikeway'},
#              'Blvd,': {'Nw Quad I-280 / Sr 35 Ic @ Jct Hayne Rd, Golf Course Dr, Skyline Blvd,'},
#              'Box': {'PO Box 5259'},
#              'Bradshaw': {'Bradshaw'},
#              'Bridge': {'Pier 1  SM- Hayward Bridge'},
#              'Bridgeway': {'Bridgeway'},
#              'Broadway': {'Broadway', 'North Broadway'},
#              'Bruno': {'Serra San Bruno'},
#              'Building': {'Ferry Building', 'Multi Use Building'},
#              'C': {'Plymouth Street #C', 'Sierra Ct #C'},
#              'C-1': {'Sunrise Blvd., Suite C-1'},
#              'CA': {'Zanker Rd., San Jose, CA', 'Zanker Road, San Jose, CA'},
#              'CA-12': {'CA-12'},
#              'CA-88': {'CA-88'},
#              'CT': {'Isles CT'},
#              'Ca': {'Pera Dr at Escuela Drive, Rancho Murieta, Ca 95683'},
#              'California': {'California'},
#              'Calle': {'La Calle'},
#              'Cay': {'Cavalla Cay'},
#              'Cedar': {'Cedar'},
#              'Central': {'Plaza Central'},
#              'Chestnut': {'Chestnut'},
#              'Clemente': {'San Clemente'},
#              'Cnr': {'@ Sunrise Blvd Nw Cnr'},
#              'Corcoran': {'425 Corcoran'},
#              'Corners': {'Midrock Corners'},
#              'Crati': {'Piane Crati'},
#              'Creek': {'Stevens Creek'},
#              'Cres': {'Wellesley Cres'},
#              'Crescent': {'Clarendon Crescent', 'Wellesley Crescent'},
#              'Cross': {'1345 Wooden Vly Cross', 'Hwy 29 at Ruthf Cross'},
#              'Cruz': {'Calle Cruz'},
#              'Cumbre': {'Via la Cumbre'},
#              'Cut': {'Short Cut'},
#              'Cut-Off': {'Butano Cut-Off'},
#              'D': {'Avenue D',
#               'Broadway #D',
#               'El Camino Real #D',
#               'Marina Boulevard Building D'},
#              'Dorado': {'El Dorado'},
#              'E': {'911 Donaldson Way E', 'Avenue E', 'Tribute Road, Suite E'},
#              'East': {'1st Street East',
#               '2nd Street East',
#               '8th Street East',
#               'Buena Vista Avenue East',
#               'Fourth Street East',
#               'Francisco Blvd East',
#               'Francisco Boulevard East',
#               'Ne Quad Benicia Rd / I-80 Ic @ Lincoln Rd East',
#               'Park Circle East',
#               'Rio Robles East',
#               'Sir Francis Drake Boulevard East',
#               'Vanderbilt Court East'},
#              'Embarcadero': {'Embarcadero', 'The Embarcadero'},
#              'Escarpado': {'El Escarpado'},
#              'Esplanade': {'Esplanade'},
#              'Esplendor': {'Via Esplendor'},
#              'Esquela': {'Camina Esquela'},
#              'Estates': {'Heatherwood Estates'},
#              'Evelyn': {'West Evelyn'},
#              'Extension': {'I Street Extension',
#               'Mission Street Extension',
#               'Old Davis Road Extension'},
#              'F': {'Avenue F', 'Port Rd F'},
#              'Ferlinghetti': {'Via Ferlinghetti'},
#              'Floor': {'11th Street, Fifth Floor'},
#              'Flores': {'Terreno De Flores'},
#              'Francisco': {'19th & Linda San Francisco'},
#              'Franklin': {'Franklin'},
#              'Freeway': {'MacArthur Freeway'},
#              'Front': {'Front'},
#              'Galvez': {'Galvez'},
#              'Galway': {'Galway\n'},
#              'Garden': {'Scott Avenue Garden'},
#              'Gardens': {'Wildwood Gardens'},
#              'Gough': {'Gough'},
#              'Grande': {'Via Grande'},
#              'Green': {'Miranda Green'},
#              'Grove': {'Aspen Grove'},
#              'Gularte': {'Paseo Gularte'},
#              'Gulch': {'Rodeo Creek Gulch'},
#              'H': {'Avenue H', 'Opportunity St #H'},
#              'HWY': {'N HWY 88'},
#              'Hall': {'McCone Hall'},
#              'Hamilton': {'Hamilton', 'Mount Hamilton'},
#              'Hawkins': {'A B C D E F Hawkins'},
#              'Hill': {'Blossom Hill'},
#              'I-280': {'Page Mill Rd @ Arastradero Rd Int S Of I-280'},
#              'I-580': {'E Of Center St @ I-580'},
#              'I-580)': {'N Side Of Foothill Blvd @ John Dr (Near I-580)',
#               'Portola Near Alviso Place, (1/2 Mi From I-580)'},
#              'I-80': {'Nw Cnr Peabody Rd / Cliffside Dr Int @ I-80',
#               'Richmond Pkwy @ I-80'},
#              'Ic': {'Ne & Se Quads Us 101 / Atherton Ave Ic',
#               'Ne & Se Quads Us 101 / Rowland Blvd Ic',
#               'Ne Quad I-280 / Edgewood Rd Ic',
#               'Nw Cnr Of Curtola Pkwy & Lemon St @ I-780 025 Mi W Of I-780 / I-80 Ic',
#               'Nw Quad Green Valley Rd / I-80 Ic',
#               'Nw Quad Sr 84 / Ardenwood Blvd Ic',
#               'Se Quad Of E 2nd St / I-780 Ic',
#               'Se Quad Sr 238 (Mission Blvd) / I-680 Ic',
#               'Se Quad Sr 92 / Ralston Ic',
#               'Sw Cnr Of Curtola Pkwy & Lemon St @ I-780 025 Mi W Of I-780 / I-80 Ic',
#               'Sw Of Sr 29 / Imola Ave Ic',
#               'Sw Quad Enterprise Dr / I-80 Ic'},
#              'Ingoglia': {'Via Ingoglia'},
#              'Int': {'012 Mi Ne Of Sr 1 / Linda Mar Blvd Int',
#               'Main St & Rr Ave Int',
#               'S/E Quad I-5 / Sr 12 Int',
#               'S/E Quad Sr 99 / Sr 12 Int',
#               'Se Cnr  Sheldon Rd Int',
#               'Se Quad Sr 1 / Crespi Dr Int',
#               'Sw Quad I-280 / Sr 84 Ic Woodside Rd & Linderbrook Rd Int'},
#              'Irwin': {'Under Us 101 Btwn 3rd St & Mission Ave Btwn Hetherton & Irwin'},
#              'Isle': {'Caribe Isle', 'Dolphin Isle'},
#              'Jefferson': {'Third & Jefferson'},
#              'Julian': {'West Julian'},
#              'Key': {'Montego Key'},
#              'King': {'King'},
#              'Knxville': {'4454 Berryessa Knxville'},
#              'Lagoon': {'Del Oro Lagoon'},
#              'Landing': {'Hamilton Landing'},
#              'Las': {'Alameda De Las'},
#              'Latrobe': {'S Of Us 50, E Side Of Latrobe'},
#              'Leslie': {'Leslie'},
#              'Lindbergh': {'Ne Quad Us 101 / 3rd Ave Off Lindbergh'},
#              'Loma': {'La Loma'},
#              'Lugano': {'Via Lugano'},
#              'Luna': {'Calle de Luna'},
#              'M': {'Avenue M', 'Port Rd M'},
#              'Macdonald': {'Macdonald'},
#              'Maclane': {'Maclane'},
#              'Madrid': {'Corte de Madrid'},
#              'Manzanita': {'Manzanita'},
#              'Mar': {'Camino del Mar', 'El Camino del Mar', 'Rancho Del Mar'},
#              'Marina': {'Pacific Marina', 'San Leandro Marina'},
#              'Marino': {'Via San Marino'},
#              'Marketplace': {'The Marketplace'},
#              'Mason': {'Fort Mason', 'Mason'},
#              'Meadowood': {'Meadowood'},
#              'Merrill': {'Merrill'},
#              'Mission': {'Mission'},
#              'Monte': {'North Via Monte'},
#              'Montgomery': {'New Montgomery'},
#              'N': {'El Camino Real N', 'Petaluma Blvd N'},
#              'NW': {'Wisconsin Ave NW'},
#              'Napoli': {'Via Napoli'},
#              'Ness': {'Van Ness'},
#              'No.': {'California Highway 16, House No. 1'},
#              'Norte': {'Via Vaquero Norte'},
#              'North': {'Cabrillo Highway North',
#               'Gravenstein Highway North',
#               'Magnolia Drive North',
#               'Mission Bay Boulevard North',
#               'Petaluma Boulevard North',
#               'Walnut Circle North'},
#              'Northgate': {'Northgate'},
#              'Oak': {'Garden Oak'},
#              'Oakridge': {'Oakridge'},
#              'Oaks': {'North Fair Oaks', 'Waverley Oaks'},
#              'One': {'Highway One'},
#              'Ora': {'Avenue Del Ora'},
#              'Oro': {'Via del Oro', 'Vista De Oro'},
#              'Ortega': {'Via Ortega'},
#              'PH': {'Bridle PH'},
#              'PK': {'Trinity PK', 'Val Dervin PK'},
#              'PM': {'San Mateo 35 PM 10'},
#              'PZ': {'Portage PZ', 'St Marks PZ'},
#              'Pablo': {'Camino Pablo', 'Via Juan Pablo'},
#              'Pacific': {'Pacific'},
#              'Padre': {'Via Padre',
#               'Via Padre #23',
#               'Via Padre #25',
#               'Via Padre #27',
#               'Via Padre #29',
#               'Via Padre #31'},
#              'Palamos': {'Via Palamos'},
#              'Palms': {'Avenue of the Palms'},
#              'Paraiso': {'El Camino Paraiso'},
#              'Paviso': {'Via Paviso'},
#              'Pier': {'Pier 39'},
#              'Piero': {'Avenida Del Piero'},
#              'Pkwy': {'Community Pkwy',
#               'Del Valle Pkwy',
#               'Oak Ave Pkwy',
#               'Technology Pkwy'},
#              'PlaceZ': {'Elkhorn PlaceZ', 'Town Center PlaceZ'},
#              'Plz': {'Toro Plz', 'Woodside Plz'},
#              'Point': {'Portsmouth Point'},
#              'Pollard': {'Pollard'},
#              'Portofino': {'Via Portofino'},
#              'Powell': {'Bay and Powell'},
#              'Prado': {'Nw Of Us 101 @ Nave Dr Oc & Alameda Del Prado'},
#              'Presada': {'Paseo Presada'},
#              'Pueblo': {'Via Pueblo'},
#              'Pulgas': {'Alamed de las Pulgas',
#               'Alameda De Las Pulgas',
#               'Alameda de Las Pulgas',
#               'Alameda de las Pulgas',
#               'Avlameda de las Pulgas'},
#              'Quad': {'North Quad'},
#              'RD': {'3132 MT VEEDER RD'},
#              'Ramon': {'815 Camino Ramon', 'Camino Ramon'},
#              'Ramps': {'@ Pasatiempo Sb Ramps'},
#              'Raod': {'Orchard Raod'},
#              'Reef': {'Bahama Reef'},
#              'Rey': {'9225 Calle Del Rey'},
#              'Rhein': {'Stein Am Rhein'},
#              'Ridge': {'Roble Ridge', 'Skyline Ridge'},
#              'Robles': {'Dante Robles'},
#              'Rock': {'Mission Rock'},
#              'Rodriguez': {'Via Rodriguez'},
#              'Route': {'East State Route 26',
#               'East State Route 4',
#               'East State Route 88',
#               'San Francisco Bicycle Route 2',
#               'West State Route 4'},
#              'Row': {'Alvarado Row', 'Santana Row'},
#              'Rte': {'13th Ave Rte 99',
#               '3rd St / Rte 50',
#               '47th Avenue / Rte 99'},
#              'Run': {'Martini Run', 'Quail Run', 'Whippett Run'},
#              'Russell': {'Russell'},
#              'S': {'Gravenstein Hwy S',
#               'Monterey St 402 6t S',
#               'Third & 310 Fourth S'},
#              'ST': {'L ST'},
#              'STE': {'Showers Drive STE 2', 'Showers Drive STE 7'},
#              'Seabright': {'Seabright'},
#              'Serra': {'Via Serra'},
#              'Seville': {'Corte de Seville'},
#              'Shores': {'Calypso Shores'},
#              'Side': {'Elkhorn Blvd Sw Side',
#               'Twin Cities Rd (Sr 104) / Sr /99 Int  Se Side'},
#              'Siding': {'Bonair Siding'},
#              'Sobrante': {'Camino Sobrante'},
#              'Sol': {'Tierra Del Sol'},
#              'Sorrento': {'Via Sorrento'},
#              'South': {'Brooks Road South',
#               'Cabrillo Highway South',
#               'Governors Avenue South',
#               'Gravenstein Highway South',
#               'Magnolia Drive South',
#               'Petaluma Boulevard South',
#               'Saint Helena Highway South',
#               'Silverado Trail South',
#               'Walnut Circle South'},
#              'Southgate': {'Southgate'},
#              'Sp': {'Fairview Road Sp 56'},
#              'Spencer': {'E & W Of  Us 101 @ Monte Mar & Spencer'},
#              'Sq': {'Evergreen Village Sq'},
#              'Sr': {'In "Y" Jct Of Sr 121 / Sr 116',
#               'Main Street At Sr 12',
#               'Pacheco Blvd @ Blum Rd N Of Sr 4',
#               'W Of Us 101 @ Jct Sr 1',
#               'W Side Of Us 101 @ Sr 116'},
#              'St/Rte': {'2nd St/Rte 5'},
#              'Stairway': {'Vallejo Street Stairway'},
#              'Stanford': {'Stanford'},
#              'Station': {'Tennant Station'},
#              'Ste': {'Great America Pkwy Ste 201', 'Sansome Street Ste 730'},
#              'Steps': {'Bancroft Steps'},
#              'Stockton': {'Geneva Pt Dr @ Stockton'},
#              'Stores': {'Across Street From Factory Outlet Stores'},
#              'Streer': {'Salvio Streer'},
#              'Suite': {'2nd St Suite 330',
#               'Doolittle Dr, Suite 15',
#               'Greenback Lane, Suite 310',
#               'Market Street Suite 3658',
#               'Sansome Street Suite 730',
#               'Stewart Drive Suite #1',
#               'University Dr. Suite 3',
#               'West Angela Street, Suite 110',
#               'West Evelyn Avenue Suite #114',
#               'Woodside Road, Suite 100',
#               'Woodside Road, Suite 155'},
#              'Sur': {'Via Vaquero Sur'},
#              'Tahualami': {'Tahualami'},
#              'Tassajara': {'Camino Tassajara'},
#              'Telegraph': {'3605 Telegraph'},
#              'Toyon': {'Upper Toyon'},
#              'Uppr': {'Freeport Blvd Uppr'},
#              'Us': {'Nw Quad Lincoln Ave / Us 101',
#               'Se Quad Smith Ranch Rd / Us 101'},
#              'Vallejo': {'Vallejo'},
#              'Ventana': {'Via Ventana'},
#              'Ventura': {'Via Ventura'},
#              'Vera': {'Villa Vera'},
#              'Verda': {'Valle Verda'},
#              'Via': {'La Casa Via'},
#              'View': {'Norwood View'},
#              'Village': {'Seascape Village', 'Town and Country Village'},
#              'Vista': {'350 Buena Vista', 'Via de la Vista', 'Villa Vista'},
#              'Volante': {'Via Volante'},
#              'Way)': {'Congress Spring Road (Big Basin Way)'},
#              'Wedemeyer': {'Wedemeyer'},
#              'West': {'1st Street West',
#               '2nd Street West',
#               '3rd Street West',
#               '5th Street West',
#               '7th Street West',
#               'Buena Vista Avenue West',
#               'Campus Dr. West',
#               'Campus Drive West',
#               'Embarcadero West',
#               'Francisco Boulevard West',
#               'Gateway Road West',
#               'Industrial Parkway West',
#               'Lincoln Road West',
#               'Park Circle West',
#               'Portage Bay West',
#               'Vanderbilt Court West',
#               'West'},
#              'Wharf': {'Fishermans Wharf'},
#              'Winchester': {'Winchester'},
#              'Yolanda': {'Corte Yolanda'},
#              'a': {'1st St #a',
#               'Monterey St #a',
#               'Pacheco Pass Hwy #a',
#               'Powell St #a'},
#              'arrowhead': {'lake arrowhead'},
#              'ave': {'wilcox ave'},
#              'b': {'Kane Dr #b', 'Technology Pkwy #b'},
#              'broadway': {'broadway'},
#              'c': {'San Juan Rd #c'},
#              'ca': {'6023 Joaquin murieta ave,newark, ca'},
#              'crt': {'galway crt'},
#              'd1': {'Nash Rd #d1'},
#              'dunne': {'San Felipe Rd #dunne'},
#              'front': {'front'},
#              'robles': {'rio robles'},
#              'side': {'San Juan Rd #side'},
#              'square': {'33 union square'},
#              'sundale': {'sundale'}})

# %%
[k for k in post_codes if len(k) > 10]
# Out:
# ['17 Via Padre, San Benito County, CA, -',
#  '1371 Westside Blvd, Hollister, CA 95023',
#  '660 Westside Blvd, Hollister, CA 95023',
#  '18 Monterey St, San Juan Bautista, CA 95045',
#  '200 Western Ct, Hollister, CA 95023',
#  '1600 Citation Way, Hollister, CA 95023',
#  '17 Ahwahnee St, San Juan Bautista, CA 95045',
#  '439 Snyder Ave, Aromas, CA 95004',
#  '1123 1st St, San Juan Bautista, CA 95045',
#  '981 Prospect Ave, Hollister, CA 95023',
#  '32 Via Padre',
#  '293 Westside Blvd, Hollister, CA 95023',
#  '2900 Fairview Rd, Hollister, CA 95023',
#  '71 Westside Blvd, Hollister, CA 95023',
#  '171 Westside Blvd, Hollister, CA 95023',
#  '23 Ahwahnee St, San Juan Bautista, CA 95045',
#  '2 Donner St, San Juan Bautista, CA 95045',
#  '270 Prater Way, Hollister, CA 95023',
#  '121 Westside Blvd, Hollister, CA 95023',
#  '340 Prater Way, Hollister, CA 95023',
#  '1 Donner St, San Juan Bautista, CA 95045',
#  '710 Kirkpatrick Dr, Hollister, CA 95023',
#  '38 Monterey St, San Juan Bautista, CA 95045',
#  '283 Willow Dr, Hollister, CA 95023',
#  '21 Ahwahnee St, San Juan Bautista, CA 95045',
#  '2300 Salinas Rd, San Benito County, CA, -',
#  '293 Willow Dr, Hollister, CA 95023',
#  '1621 San Jua Rd, San Benito County, CA, -',
#  '671 Wiebe Way, Hollister, CA 95023',
#  '1240 Westside Blvd, Hollister, CA 95023',
#  '1 Via Padre #29, San Benito County, CA, -',
#  '5 Via Padre, San Benito County, CA, -',
#  '1623 San Jua Rd, San Benito County, CA, -',
#  '36 Tahualami, San Benito County, CA, -',
#  '14 Via Serra, San Benito County, CA, -',
#  '12 Ahwahnee St, San Juan Bautista, CA 95045',
#  '302 Willow Dr, Hollister, CA 95023',
#  '37 Tahualami St, San Benito County, CA, -',
#  '28 Via Serra, San Benito County, CA, -',
#  '13 Ahwahnee St, San Juan Bautista, CA 95045',
#  '94305;94309',
#  '6711 Airline Hwy, Tres Pinos, CA 95023',
#  '6000 Diablo Hills Rd, Tres Pinos, CA 95023',
#  '51 Westside Blvd, Hollister, CA 95023',
#  '660 Wiebe Way, Hollister, CA 95023',
#  '28 Via Padre',
#  '303 Willow Dr, Hollister, CA 95023',
#  '11 Jefferson St, San Juan Bautista, CA 95045',
#  '1 Ahwahnee St, San Juan Bautista, CA 95045',
#  u'\u200e94582-5009',
#  '701 Westside Blvd, Hollister, CA 95023',
#  '10 Via Padre',
#  '31 Wright Rd, Hollister, CA 95023',
#  '6170 Hillside Rd, San Juan Bautista, CA 95045',
#  '233 Willow Dr, Hollister, CA 95023',
#  '19 Via Serra, San Benito County, CA, -',
#  '53 Franklin, San Juan Bautista, CA 95045',
#  '240 Westside Blvd, Hollister, CA 95023',
#  '202 Willow Dr, Hollister, CA 95023',
#  '191 Westside Blvd, Hollister, CA 95023',
#  '210 Windmill Dr, Hollister, CA 95023',
#  '750 West St, Hollister, CA 95023',
#  '26 Via Serra, San Benito County, CA, -',
#  '7 Via Padre, San Benito County, CA, -',
#  '151 Santa Ana Rd, San Benito County, CA, -',
#  '501 Fairview Rd, Hollister, CA 95023',
#  '201 Western Ct, Hollister, CA 95023',
#  '11 Via Serra, San Benito County, CA, -',
#  '1006 3rd St, San Juan Bautista, CA 95045',
#  '900 2nd St, San Juan Bautista, CA 95045',
#  '297 Westside Blvd, Hollister, CA 95023',
#  '640 Wiebe Way, Hollister, CA 95023',
#  '1470 Westside Blvd, Hollister, CA 95023',
#  '262 Willow Dr, Hollister, CA 95023',
#  '1350 Westside Blvd, Hollister, CA 95023',
#  '1250 Westside Blvd, Hollister, CA 95023',
#  '63 Washington St, San Benito County, CA, -',
#  '88 Church St, San Juan Bautista, CA 95045',
#  '903 1st St, San Juan Bautista, CA 95045',
#  '207 The Alemeda, San Benito County, CA, -',
#  '242 Willow Dr, Hollister, CA 95023',
#  '232 Willow Dr, Hollister, CA 95023',
#  '2700 Quinn Canyon Rd, San Benito County, CA, -',
#  '181 Westside Blvd, Hollister, CA 95023',
#  '21 Failing Rd, Hollister, CA 95023',
#  '201 Prater Way, Hollister, CA 95023',
#  '7171 Diablo Hills Rd, Tres Pinos, CA 95023',
#  '801 3rd St, San Juan Bautista, CA 95045',
#  '59 Washington St, San Benito County, CA, -',
#  '200 Windmill Dr, Hollister, CA 95023',
#  '1000 San Juan Canyon Rd, San Benito County, CA, -',
#  '1121 1st St',
#  '190 Westside Blvd, Hollister, CA 95023',
#  '1119 1st St',
#  '95014-2143;95014-2144',
#  '30 Via Serra, San Benito County, CA, -',
#  '313 Willow Dr, Hollister, CA 95023',
#  '315 Larios Dr, San Juan Bautista, CA 95045',
#  '212 Willow Dr, Hollister, CA 95023',
#  '24 Via Serra, San Benito County, CA, -',
#  '6 Via Serra, San Benito County, CA, -',
#  '728 West St, Hollister, CA 95023',
#  '721 Rocks Rd, San Benito County, CA, -',
#  '79 Franklin Cir, San Juan Bautista, CA 95045',
#  '10 Ahwahnee St, San Juan Bautista, CA 95045',
#  '271 Prater Way, Hollister, CA 95023',
#  '40 Monterey St, San Juan Bautista, CA 95045',
#  '263 Willow Dr, Hollister, CA 95023',
#  '6350 4 Corners Dr, Hollister, CA 95023',
#  '11 Westside Blvd, Hollister, CA 95023',
#  '510 West St, Hollister, CA 95023',
#  '6600 Diablo Hills Rd, Tres Pinos, CA 95023',
#  '11 Kurasaki Dr, San Juan Bautista, CA 95045',
#  '305 Larios Dr, San Juan Bautista, CA 95045',
#  '19 Ahwahnee St, San Juan Bautista, CA 95045',
#  '1117 1st St',
#  'Prater Way, Hollister, CA 95023',
#  '1875 Payne Rd, San Juan Bautista, CA 95045',
#  '273 Willow Dr, Hollister, CA 95023',
#  '131 North St, Hollister, CA 95023',
#  '111 Hillside Rd, San Juan Bautista, CA 95045',
#  '7100 Diablo Hills Rd, Tres Pinos, CA 95023',
#  '11 Ahwahnee St, San Juan Bautista, CA 95045',
#  '5 Ahwahnee St, San Juan Bautista, CA 95045',
#  '2 Ahwahnee St, San Juan Bautista, CA 95045',
#  '1351 Westside Blvd, Hollister, CA 95023',
#  '18 Via Serra, San Benito County, CA, -',
#  '203 Willow Dr, Hollister, CA 95023',
#  '5 Donner St, San Juan Bautista, CA 95045',
#  '25 Via Serra, San Benito County, CA, -',
#  '252 Willow Dr, Hollister, CA 95023',
#  '6995 Diablo Hills Rd, Hollister, CA 95023',
#  '620 Wiebe Way, Hollister, CA 95023',
#  '1260 Westside Blvd, Hollister, CA 95023',
#  '1735 Santa Ana Rd, San Benito County, CA, -',
#  '630 Westside Blvd, Hollister, CA 95023',
#  '390 West St, Hollister, CA 95023',
#  '7 Ahwahnee St, San Juan Bautista, CA 95045',
#  '9 Ahwahnee St, San Juan Bautista, CA 95045',
#  '4th St & D St, Hollister, CA 95023',
#  '15 Via Padre, San Benito County, CA, -',
#  '161 Westside Blvd, Hollister, CA 95023',
#  '7 Donner St, San Juan Bautista, CA 95045',
#  '424 West St, Hollister, CA 95023',
#  '3 Donner St, San Juan Bautista, CA 95045',
#  '14 Ahwahnee St, San Juan Bautista, CA 95045',
#  '6800 Diablo Hills Rd, Tres Pinos, CA 95023',
#  '16 Monterey St, San Juan Bautista, CA 95045',
#  '155 Westside Blvd, Hollister, CA 95023',
#  '272 Willow Dr, Hollister, CA 95023',
#  '230 Prater Way, Hollister, CA 95023',
#  '641 Wiebe Way, Hollister, CA 95023',
#  '1230 Westside Blvd, Hollister, CA 95023',
#  '81 Franklin Cir, San Juan Bautista, CA 95045',
#  '14 Via Padre',
#  '13 Donner St, San Juan Bautista, CA 95045',
#  '46 Franklin St, San Juan Bautista, CA 95045',
#  '9 Via Serra, San Benito County, CA, -',
#  '4196 Salinas Rd, San Benito County, CA, -',
#  '111 Westside Blvd, Hollister, CA 95023',
#  '41 Westside Blvd, Hollister, CA 95023',
#  '53 Washington St, San Benito County, CA, -',
#  '1631 San Jua Rd, San Benito County, CA, -',
#  '1107 3rd St, San Juan Bautista, CA 95045',
#  '15 Via Serra, San Benito County, CA, -',
#  '282 Willow Dr, Hollister, CA 95023',
#  '101 Westside Blvd, Hollister, CA 95023',
#  '24 Via Padre',
#  '486 West St, Hollister, CA 95023',
#  '34 Church St, San Juan Bautista, CA 95045',
#  '3 Ahwahnee St, San Juan Bautista, CA 95045',
#  '660 Fairview Rd, Hollister, CA 95023',
#  '39 Washington St, San Benito County, CA, -',
#  '35 Tahualami St, San Benito County, CA, -',
#  '620 Westside Blvd, Hollister, CA 95023',
#  '307 East St, Hollister, CA 95023',
#  'Monterey St Sjb, San Juan Bautista, CA 95045',
#  '23 Via Serra, San Benito County, CA, -',
#  '1 Bolsa Rd, Hollister, CA 95023',
#  '220 Windmill Dr, Hollister, CA 95023',
#  '20 Via Serra, San Benito County, CA, -',
#  '635 Nash Rd, Hollister, CA 95023',
#  '39 Church St, San Juan Bautista, CA 95045',
#  '10 Via Serra, San Benito County, CA, -',
#  '107 The Alameda, San Benito County, CA, -',
#  '901 Prospect Ave, Hollister, CA 95023',
#  '411 Cole Rd, Aromas, CA 95004',
#  '7 Thomas Ln, San Benito County, CA, -',
#  '748 West St, Hollister, CA 95023',
#  '311 Prater Way, Hollister, CA 95023',
#  '430 Gateway Dr, Hollister, CA 95023',
#  '950 San Felipe Rd, San Benito County, CA, -',
#  '1125 1st St, San Juan Bautista, CA 95045',
#  '1002 3rd St, San Juan Bautista, CA 95045',
#  '31 Westside Blvd, Hollister, CA 95023',
#  '220 Western Ct, Hollister, CA 95023',
#  '241 Western Ct, Hollister, CA 95023',
#  '292 Willow Dr, Hollister, CA 95023',
#  '141 Westside Blvd, Hollister, CA 95023',
#  '6700 Diablo Hills Rd, Hollister, CA 95023',
#  '213 Willow Dr, Hollister, CA 95023',
#  '4 Ahwahnee St, San Juan Bautista, CA 95045',
#  '35 San Jose St, San Benito County, CA, -',
#  '5 Via Serra, San Benito County, CA, -',
#  '6200 Diablo Hills Rd, Hollister, CA 95023',
#  '9 Donner St, San Juan Bautista, CA 95045',
#  '8 Via Serra, San Benito County, CA, -',
#  '600 Buena Vista Rd, Hollister, CA 95023',
#  '1 Via Padre #27, San Benito County, CA, -',
#  '85 Franklin St, San Juan Bautista, CA 95045',
#  '180 Westside Blvd, Hollister, CA 95023',
#  '61 North St, Hollister, CA 95023',
#  '632 7th St, Hollister, CA 95023',
#  '221 Western Ct, Hollister, CA 95023',
#  '243 Willow Dr, Hollister, CA 95023',
#  '8 Ahwahnee St, San Juan Bautista, CA 95045',
#  '20 Via Padre',
#  '640 Westside Blvd, Hollister, CA 95023',
#  '1127 1st St, San Juan Bautista, CA 95045',
#  '3055 School Rd, San Benito County, CA, -',
#  '902 2nd St, San Juan Bautista, CA 95045',
#  '1220 Westside Blvd, Hollister, CA 95023',
#  '11 Donner St, San Juan Bautista, CA 95045',
#  '1 Via Padre #31, San Benito County, CA, -',
#  '600 Westside Blvd, Hollister, CA 95023',
#  '1641 San Jua Rd, San Benito County, CA, -',
#  '712 West St, Hollister, CA 95023',
#  '22 Via Serra, San Benito County, CA, -',
#  '12 Via Serra, San Benito County, CA, -',
#  '203 East St, Hollister, CA 95023',
#  '200 Prater Way, Hollister, CA 95023',
#  '705 3rd St, San Juan Bautista, CA 95045',
#  '19 Via Padre, San Benito County, CA, -',
#  '1 Via Padre #23, San Benito County, CA, -',
#  '190 Windmill Dr, Hollister, CA 95023',
#  '521 Quarry Rd, San Juan Bautista, CA 95004',
#  '1 Via Padre #25, San Benito County, CA, -',
#  '312 Willow Dr, Hollister, CA 95023',
#  '223 Willow Dr, Hollister, CA 95023',
#  '222 Willow Dr, Hollister, CA 95023',
#  '231 Gateway Dr, Hollister, CA 95023',
#  '120 Hillside Rd, San Juan Bautista, CA 95045',
#  '15 Donner St, San Juan Bautista, CA 95045',
#  '4200 Salinas Rd, San Benito County, CA, -',
#  '670 Westside Blvd, San Benito County, CA, -',
#  '1410 Westside Blvd, Hollister, CA 95023',
#  '796 Arriba Dr, Aromas, CA 95004',
#  '6 Ahwahnee St, San Juan Bautista, CA 95045',
#  '522 West St, Hollister, CA 95023']

# %%
counties
# Out:
# defaultdict(int,
#             {'Alameda': 261,
#              'Amador': 2,
#              'Contra Costa': 906,
#              'El Dorado': 36,
#              'Lake': 10,
#              'Marin': 873,
#              'Merced': 50,
#              'Monterey': 161,
#              'Monterey, CA': 1,
#              'Napa': 248,
#              'Sacramento': 1013,
#              'San Benito': 179,
#              'San Benito County': 6694,
#              'San Joaquin': 1258,
#              'San Mateo': 162,
#              'Santa Clara': 1689,
#              'Santa Clara County': 4,
#              'Santa Cruz': 3,
#              'Solano': 892,
#              'Sonoma': 15,
#              'Stanislaus': 454,
#              'Yolo': 789})

# %% [markdown]
# # Cleaning

# %%
def update_street_name_regex(regex, name, mapping):
    m = regex.search(name)
    if m:
        street_type = m.group(1)
        new_street_type = mapping.get(street_type)
        if new_street_type:
            name = re.sub(regex, new_street_type, name)
            return name
    
    return name

def update_street_name(name, mapping):
    new_name = update_street_name_regex(street_type_re, name, mapping)
    if new_name != name:
        return new_name
    
    new_name = update_street_name_regex(street_type_num_re, name, mapping)
    if new_name != name:
        return new_name
    
    return name

postcode_re = re.compile(r'[0-9]{5,5}$', re.IGNORECASE)
postcode_dash_re = re.compile(r'[0-9]{5,5}-[0-9]{4,4}$', re.IGNORECASE)

def has_valid_postcode(name):
    return postcode_re.search(name) is not None or postcode_dash_re.search(name) is not None

def update_postcode(name):
    m = postcode_re.search(name)
    if m is None:
        m = postcode_dash_re.search(name)
    return m.group()

county_re = re.compile(r'(.+) County', re.IGNORECASE)

def update_county(name):
    m = county_re.search(name)
    if m:
        name = m.group(1)
    return name

# %%
postcode1 = "94588"
postcode2 = "94588-1234"
address = "1 Donner St, San Juan Bautista, CA 95045"
address2 = "950 San Felipe Rd, San Benito County, CA, -"

postcode_re = re.compile(r'[0-9]{5,5}$', re.IGNORECASE)
postcode_dash_re = re.compile(r'[0-9]{5,5}-[0-9]{4,4}$', re.IGNORECASE)

# %%
update_postcode(address)
# Out:
# '95045'

# %%
display(update_street_name("2nd st", mapping))
display(update_street_name("Northgate Blvd #100", mapping))
# Out:
# '2nd Street'
# 'Northgate Boulevard #100'

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = ["version", "changeset", "timestamp", "user", "uid"]
POSITION = ["lat", "lon"]

def has_lat_lon(element):
    return 'lat' in element.attrib and 'lon' in element.attrib

def shape_attributes(element, node):
    for attr in element.attrib:
        if attr in CREATED or attr in POSITION:
            continue
        node[attr] = element.attrib[attr]
        #print attr, element.attrib[attr]
    
    created = {}
    for attr in CREATED:
        if attr in element.attrib:
            created[attr] = element.attrib[attr]
    node['created'] = created
    
    if has_lat_lon(element):
        node['pos'] = [float(element.attrib['lat']), float(element.attrib['lon'])]

def shape_tags(element, node):
    address = {}
    for tag in element.iter("tag"):
        key = tag.attrib['k']
        value = tag.attrib['v']
        
        if is_street_name(tag):
            value = update_street_name(value, mapping)
        
        if is_postcode(tag):
            if not has_valid_postcode(value):
                continue
            value = update_postcode(value)
        
        if is_county(tag):
            value = update_county(value)
                    
        #print key, value
        if (re.search(problemchars, key) or 
            (re.search(lower, key) is None and 
            re.search(lower_colon, key) is None)):
            continue
        
        if re.search(lower_colon, key):
            key_arr = key.split(':')
            prefix = key_arr[0]
            suffix = key_arr[1]
            
            if prefix == 'addr':
                address[suffix] = value
            else:
                key = re.sub(':', "-", key)
                node[key] = value
                
            continue
        
        node[key] = value
    
    if len(address) > 0:
        #print node
        node['address'] = address    

def shape_node_refs(element, way):
    refs = []
    if element.tag == "way":
        for nd in element.iter("nd"):
            refs.append(nd.attrib['ref'])
        way['node_refs'] = refs
    
def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        # Handle top-level element
        node['type'] = element.tag
        
        shape_attributes(element, node)   
        
        # Handle tags
        shape_tags(element, node)
        
        # Handle node refs for way
        shape_node_refs(element, node)
        
        #print node
        return node
    else:
        return None

# %%
def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        
        for i, elem in enumerate(get_element(file_in)):
            el = shape_element(elem)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %%
process_map(OSM_FILE, True)
