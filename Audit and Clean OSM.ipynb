# %%
import xml.etree.cElementTree as ET
import pprint
import re
from collections import defaultdict
from IPython.display import display
import operator
import codecs
import json

# %%
#OSM_FILE = "sample-k-25.osm"
OSM_FILE = "sample-k-100.osm"

street_type_re = re.compile(r'(\b\S+\.?)$', re.IGNORECASE) # "300 Bernal Ave." or "900 Cy Ranch Drive"
street_type_num_re = re.compile(r'(\b\S+\.?)(?= #?[0-9]+$)', re.IGNORECASE) # "20 Cal Avenue #32" or "15 Stevens Creek Hwy 2"

# %%
# Examples of using street_type_num_re
m = street_type_num_re.search("2030 Hwy 1")
print(m.group(1))

m = street_type_num_re.search("Old Bernal Ave #1")
print(m.group(1))
# Out:
# Hwy
# Ave

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# %%
def count_high_level_tags(filename):
    tags = defaultdict(int)
    
    #for i, elem in enumerate(get_element(OSM_FILE)):
    for event, elem in ET.iterparse(filename, events=('start', 'end')):
        tags[elem.tag] += 1
        
        # TODO(hkwik): I know I ought to clear the root, but not sure about elem.tag in tags.
        # Once I understand, I'll put this in.
        # if event == 'end' and elem.tag in tags: 
        #    root.clear()
    
    return tags

count_high_level_tags(OSM_FILE)
# Out:
# defaultdict(int,
#             {'member': 2866,
#              'nd': 290588,
#              'node': 245418,
#              'osm': 2,
#              'relation': 220,
#              'tag': 110246,
#              'way': 25960})

# %% [markdown]
# # Audit Keys

# %%
def count_keys(tag, keys):
    k = tag.attrib['k']
    keys[k] += 1
    pass

def audit_keys(osm_file):
    keys = defaultdict(int)
    for i, elem in enumerate(get_element(osm_file, tags=['node', 'way'])):
        for tag in elem.iter('tag'):
            count_keys(tag, keys)
    
    #osm_file.close()
    return keys

# %%
keys = audit_keys(OSM_FILE)

sorted_keys = sorted(keys.items(), key=operator.itemgetter(1))
sorted_keys[::-1]
# Out:
# [('building', 7698),
#  ('highway', 4440),
#  ('name', 2948),
#  ('addr:housenumber', 2265),
#  ('addr:street', 2157),
#  ('tiger:county', 2087),
#  ('tiger:cfcc', 1990),
#  ('addr:city', 1873),
#  ('tiger:name_base', 1806),
#  ('source', 1747),
#  ('tiger:name_type', 1719),
#  ('tiger:reviewed', 1461),
#  ('tiger:zip_left', 1391),
#  ('tiger:zip_right', 1322),
#  ('tiger:tlid', 973),
#  ('tiger:source', 965),
#  ('addr:state', 921),
#  ('tiger:separated', 919),
#  ('addr:postcode', 754),
#  ('oneway', 662),
#  ('height', 626),
#  ('amenity', 520),
#  ('service', 483),
#  ('lanes', 445),
#  ('created_by', 441),
#  ('landuse', 404),
#  ('waterway', 390),
#  ('power', 298),
#  ('surface', 297),
#  ('tiger:upload_uuid', 285),
#  ('maxspeed', 279),
#  ('bicycle', 274),
#  ('paloalto_ca:id', 252),
#  ('natural', 244),
#  ('access', 203),
#  ('leisure', 201),
#  ('cycleway', 198),
#  ('foot', 185),
#  ('redwood_city_ca:bld_gid', 185),
#  ('nhd:reach_code', 177),
#  ('ref', 176),
#  ('layer', 175),
#  ('gnis:fcode', 171),
#  ('nhd:fdate', 171),
#  ('redwood_city_ca:addr_id', 171),
#  ('nhd:com_id', 170),
#  ('sidewalk', 160),
#  ('addr:county', 156),
#  ('turn:lanes', 156),
#  ('barrier', 152),
#  ('gnis:ftype', 142),
#  ('boat', 142),
#  ('scvwd:ROUTEID', 140),
#  ('railway', 139),
#  ('addr:country', 137),
#  ('ele', 128),
#  ('attribution', 128),
#  ('tiger:name_base_1', 122),
#  ('shop', 120),
#  ('crossing', 116),
#  ('gnis:feature_id', 107),
#  ('intermittent', 101),
#  ('tiger:name_direction_prefix', 94),
#  ('gnis:created', 93),
#  ('gnis:county_id', 89),
#  ('gnis:state_id', 89),
#  ('hgv', 88),
#  ('bridge', 85),
#  ('operator', 85),
#  ('name_1', 84),
#  ('description', 79),
#  ('emergency', 76),
#  ('tiger:name_type_1', 73),
#  ('FMMP_reviewed', 70),
#  ('FMMP_modified', 70),
#  ('building:levels', 68),
#  ('sbc_parcel', 67),
#  ('sbc_apn', 67),
#  ('sport', 67),
#  ('sbc_id', 67),
#  ('source:maxspeed', 64),
#  ('horse', 63),
#  ('website', 60),
#  ('cuisine', 58),
#  ('area', 55),
#  ('note', 55),
#  ('man_made', 50),
#  ('acres', 50),
#  ('note:mk408', 48),
#  ('hgv:national_network', 47),
#  ('generator:source', 46),
#  ('tunnel', 46),
#  ('massgis:cat', 45),
#  ('tiger:zip_left_1', 44),
#  ('turn:lanes:backward', 44),
#  ('tourism', 43),
#  ('phone', 43),
#  ('turn:lanes:forward', 42),
#  ('lanes:backward', 39),
#  ('source:hgv:national_network', 39),
#  ('lanes:forward', 36),
#  ('footway', 35),
#  ('parking', 35),
#  ('motor_vehicle', 35),
#  ('leaf_type', 34),
#  ('old_ref', 33),
#  ('traffic_calming', 33),
#  ('scvwd:FACILITY', 31),
#  ('taxon', 30),
#  ('religion', 29),
#  ('HFCS', 29),
#  ('wheelchair', 29),
#  ('species:en', 28),
#  ('gauge', 27),
#  ('source:addr', 27),
#  ('seasonal', 25),
#  ('addr:full', 25),
#  ('NO_PRMT', 23),
#  ('opening_hours', 23),
#  ('NO_SITE', 23),
#  ('cycleway:right', 23),
#  ('fields', 23),
#  ('COMM_CODE', 23),
#  ('lcn_ref', 23),
#  ('len', 23),
#  ('fields_ID', 23),
#  ('lit', 22),
#  ('crop', 22),
#  ('denomination', 21),
#  ('public_transport', 21),
#  ('maxspeed:hgv', 21),
#  ('aeroway', 21),
#  ('noexit', 21),
#  ('NO_PRMT_SI', 20),
#  ('ID', 20),
#  ('electrified', 20),
#  ('entrance', 19),
#  ('maxspeed:trailer', 19),
#  ('place', 19),
#  ('addr:paloaltoca_id', 18),
#  ('leaf_cycle', 18),
#  ('usage', 17),
#  ('gnis:id', 17),
#  ('golf', 17),
#  ('NHS', 17),
#  ('redwood_city_ca:bldg_id', 16),
#  ('SHAPE_len', 16),
#  ('gnis:county_name', 16),
#  ('shelter', 15),
#  ('src:id', 15),
#  ('old_name', 15),
#  ('tiger:zip_right_1', 15),
#  ('capacity', 15),
#  ('source:hgv:state_network', 15),
#  ('hgv:state_network', 15),
#  ('SHAPE_area', 15),
#  ('bus', 14),
#  ('source:name', 14),
#  ('is_in', 14),
#  ('tiger:zip_left_2', 13),
#  ('office', 13),
#  ('Shape_len', 12),
#  ('gnis:import_uuid', 12),
#  ('trolley_wire', 12),
#  ('hov', 12),
#  ('Shape_area', 12),
#  ('fee', 12),
#  ('water', 12),
#  ('gnis:reviewed', 11),
#  ('Zoning', 11),
#  ('SHAPE_STAr', 11),
#  ('tracktype', 11),
#  ('OBJECTID', 11),
#  ('owner', 11),
#  ('SHAPE_STLe', 11),
#  ('covered', 11),
#  ('note:lanes', 11),
#  ('GENERIC', 11),
#  ('addr:unit', 11),
#  ('gnis:Class', 10),
#  ('gnis:ST_alpha', 10),
#  ('gnis:County', 10),
#  ('gnis:ST_num', 10),
#  ('import_uuid', 10),
#  ('Zone', 10),
#  ('survey:date', 10),
#  ('gnis:County_num', 10),
#  ('Attribution', 10),
#  ('Atribution', 9),
#  ('scvwd:COVERED', 9),
#  ('alt_name', 9),
#  ('historic', 9),
#  ('capture', 9),
#  ('OPER_ADD', 9),
#  ('DT_ADD', 9),
#  ('P_S_COMM', 8),
#  ('brand', 8),
#  ('tiger:name_base_2', 8),
#  ('Tiger:MTFCC', 8),
#  ('voltage', 8),
#  ('direction', 8),
#  ('tiger:name_direction_prefix_1', 8),
#  ('bench', 8),
#  ('route_ref', 8),
#  ('PMT_SITE', 8),
#  ('tiger:MTFCC', 8),
#  ('wetland', 8),
#  ('COUNTYFP', 8),
#  ('destination', 8),
#  ('STATEFP', 8),
#  ('DT_MANT', 8),
#  ('MTFCC', 8),
#  ('ticker', 8),
#  ('traffic_signals:direction', 7),
#  ('lcn', 7),
#  ('fixme', 7),
#  ('smoking', 7),
#  ('wikipedia', 7),
#  ('ALAND', 7),
#  ('length', 7),
#  ('source:geometry', 7),
#  ('AWATER', 7),
#  ('junction', 7),
#  ('latitude', 7),
#  ('mrosd:version', 7),
#  ('information', 7),
#  ('mrosd:preserve', 7),
#  ('exit_to', 7),
#  ('longitude', 7),
#  ('level', 7),
#  ('seamark:type', 7),
#  ('cables', 6),
#  ('incline', 6),
#  ('bicycle_parking', 6),
#  ('tiger:name_direction_suffix', 6),
#  ('addr:housename', 6),
#  ('route', 6),
#  ('segregated', 6),
#  ('network', 6),
#  ('smoothness', 6),
#  ('outdoor_seating', 6),
#  ('landcover', 6),
#  ('FIXME:bicycle', 5),
#  ('contact:phone', 5),
#  ('addr:flats', 5),
#  ('utility_wires', 5),
#  ('caltrans:district', 5),
#  ('tiger:zip_right_2', 5),
#  ('fence_type', 5),
#  ('BLDGID', 5),
#  ('tiger:zip_left_3', 5),
#  ('addr:interpolation', 5),
#  ('width', 5),
#  ('OBJNAME', 5),
#  ('frequency', 5),
#  ('designation', 5),
#  ('motorcycle', 5),
#  ('AREA_M2', 5),
#  ('takeaway', 5),
#  ('FIXME', 5),
#  ('old_railway_operator', 5),
#  ('rwc_ca:buildingid', 5),
#  ('tiger:LINEARID', 5),
#  ('traffic_signals', 4),
#  ('building:material', 4),
#  ('change:lanes', 4),
#  ('unsigned_ref', 4),
#  ('source:pkey', 4),
#  ('name:en', 4),
#  ('gnis:feature_type', 4),
#  ('dog', 4),
#  ('caltrans:dynsegpm', 4),
#  ('vta:id', 4),
#  ('AREAID', 4),
#  ('outside', 4),
#  ('bulb', 4),
#  ('caltrans:type', 4),
#  ('wifi', 3),
#  ('is_in:country_code', 3),
#  ('fire_hydrant:type', 3),
#  ('recycling_type', 3),
#  ('drive_through', 3),
#  ('construction', 3),
#  ('tiger:PCINECTA', 3),
#  ('tiger:CPI', 3),
#  ('tiger:FUNCSTAT', 3),
#  ('contact:website', 3),
#  ('addr:side', 3),
#  ('tiger:CLASSFP', 3),
#  ('destination:ref', 3),
#  ('internet_access', 3),
#  ('tiger:PLCIDFP', 3),
#  ('addr:1:housenumber', 3),
#  ('location', 3),
#  ('tiger:mtfcc', 3),
#  ('toilets:disposal', 3),
#  ('overtaking', 3),
#  ('drinking_water', 3),
#  ('source_ref', 3),
#  ('tiger:PLACEFP', 3),
#  ('board_type', 3),
#  ('boundary', 3),
#  ('tiger:STATEFP', 3),
#  ('elev', 3),
#  ('quantity', 3),
#  ('tiger:name_direction_suffix_1', 3),
#  ('placement', 3),
#  ('is_in:state', 3),
#  ('sac_scale', 3),
#  ('tiger:LSAD', 3),
#  ('tiger:PCICBSA', 3),
#  ('tiger:NAMELSAD', 3),
#  ('tiger:PLACENS', 3),
#  ('atm', 3),
#  ('fire_hydrant:position', 3),
#  ('Tiger:HYDROID', 3),
#  ('house', 3),
#  ('tiger:RTTYP', 3),
#  ('wetap:status', 3),
#  ('tiger:NAME', 3),
#  ('tiger:name_type_2', 3),
#  ('microbrewery', 3),
#  ('roof:shape', 3),
#  ('road_marking', 3),
#  ('pipe_type', 2),
#  ('denotation', 2),
#  ('is_in:country', 2),
#  ('gns:id', 2),
#  ('is_in:state_code', 2),
#  ('seamark:light:character', 2),
#  ('seamark:beacon_lateral:category', 2),
#  ('recycling:cans', 2),
#  ('nps:pets', 2),
#  ('roof:colour', 2),
#  ('parking:condition:both', 2),
#  ('proposed', 2),
#  ('nps:length', 2),
#  ('bottle', 2),
#  ('wires', 2),
#  ('status', 2),
#  ('collection_times', 2),
#  ('par', 2),
#  ('backrest', 2),
#  ('seamark:light:exhibition', 2),
#  ('toilets:position', 2),
#  ('maxheight', 2),
#  ('craft', 2),
#  ('change:lanes:forward', 2),
#  ('seamark:beacon_lateral:colour', 2),
#  ('seamark:name', 2),
#  ('change:lanes:backward', 2),
#  ('indoor', 2),
#  ('is_in:iso_3166_2', 2),
#  ('importuuid', 2),
#  ('sfgov:OBJNAME', 2),
#  ('irrigated', 2),
#  ('generator:method', 2),
#  ('seamark:light:period', 2),
#  ('minweight:hgv', 2),
#  ('park_ride', 2),
#  ('motorcar', 2),
#  ('turn:lanes:both_ways', 2),
#  ('parking:lane:both', 2),
#  ('button_operated', 2),
#  ('name_2', 2),
#  ('seamark:light:sequence', 2),
#  ('payment:bitcoin', 2),
#  ('gnis:edited', 2),
#  ('material', 2),
#  ('capacity:disabled', 2),
#  ('bicycle:lanes', 2),
#  ('destination:street', 2),
#  ('seamark:beacon_lateral:shape', 2),
#  ('handicap', 2),
#  ('history', 2),
#  ('placement:backward', 2),
#  ('seamark:light:colour', 2),
#  ('start_date', 2),
#  ('hiking', 2),
#  ('nps:trail', 2),
#  ('disused', 2),
#  ('animal', 2),
#  ('placement:forward', 2),
#  ('OPER_MANT', 2),
#  ('maxspeed:trailers', 1),
#  ('historic:name', 1),
#  ('destination:lanes:forward', 1),
#  ('hour_on', 1),
#  ('recycling:paper_packaging', 1),
#  ('scvwd:SHAPE_AREA', 1),
#  ('self_service', 1),
#  ('turn:forward', 1),
#  ('destination:backward', 1),
#  ('floating', 1),
#  ('addr:3:housenumber', 1),
#  ('source:opening_hours', 1),
#  ('official_name', 1),
#  ('seamark:rock:water_level', 1),
#  ('wetap:quality', 1),
#  ('crossing_ref', 1),
#  ('lanes:both_ways', 1),
#  ('recycling:plastic', 1),
#  ('park:type', 1),
#  ('seamark:status', 1),
#  ('recycling:glass_bottles', 1),
#  ('noaa:geohash', 1),
#  ('diaper', 1),
#  ('ford', 1),
#  ('lane', 1),
#  ('_Acres_', 1),
#  ('admin_level', 1),
#  ('tiger:name_base_3', 1),
#  ('tiger:arid', 1),
#  ('unisex', 1),
#  ('mtb:scale', 1),
#  ('facility', 1),
#  ('cinema:3D', 1),
#  ('health_specialty', 1),
#  ('tomb', 1),
#  ('payment:litecoin', 1),
#  ('supervised', 1),
#  ('source:phone', 1),
#  ('recycling:plastic_packaging', 1),
#  ('lot_no', 1),
#  ('ANSICODE', 1),
#  ('ntd_id', 1),
#  ('language:en', 1),
#  ('destination:lanes', 1),
#  ('language:es', 1),
#  ('local_ref', 1),
#  ('nps:condition', 1),
#  ('seamark:buoy_lateral:colour', 1),
#  ('wheelchair:note', 1),
#  ('destination:ref:backward', 1),
#  ('seamark:buoy_lateral:shape', 1),
#  ('sanitary_dump_station:fee', 1),
#  ('sfgov.org:OFFICE_TYP', 1),
#  ('seamark:daymark:shape', 1),
#  ('wetap:flow', 1),
#  ('scvwd:AREA_FT', 1),
#  ('building:part', 1),
#  ('Id', 1),
#  ('landmark', 1),
#  ('colour', 1),
#  ('seamark:daymark:colour', 1),
#  ('noaa:lnam', 1),
#  ('levels', 1),
#  ('addr:2:housenumber', 1),
#  ('caltrans:pctuse', 1),
#  ('addr:5:housenumber', 1),
#  ('social_facility:for', 1),
#  ('sloped_curb', 1),
#  ('abutters', 1),
#  ('railway:traffic_mode', 1),
#  ('free_flying:site', 1),
#  ('dist:blue', 1),
#  ('bridge:ref', 1),
#  ('source:date', 1),
#  ('currency:USD', 1),
#  ('mtb:scale:imba', 1),
#  ('scvwd:OBJECTID', 1),
#  ('waste', 1),
#  ('open_date', 1),
#  ('scvwd:AREA_AC', 1),
#  ('seamark:rock:quality', 1),
#  ('hoops', 1),
#  ('recycling:cartons', 1),
#  ('rwc_ca:id', 1),
#  ('finished_laundry', 1),
#  ('maxlength', 1),
#  ('_Shape_Leng_', 1),
#  ('parapet', 1),
#  ('monitoring:water_level', 1),
#  ('screen', 1),
#  ('stop:direction', 1),
#  ('seamark:buoy_lateral:category', 1),
#  ('scvwd:WB_TYPE', 1),
#  ('alterations', 1),
#  ('name:es', 1),
#  ('sfgov.org:OBJECTID', 1),
#  ('email', 1),
#  ('hour_off', 1),
#  ('destination:ref:lanes:forward', 1),
#  ('addr:4:housenumber', 1),
#  ('trail_visibility', 1),
#  ('stop', 1),
#  ('iata', 1),
#  ('turn_restrictions', 1),
#  ('telecom', 1),
#  ('state', 1),
#  ('ref:faa', 1),
#  ('social_facility', 1),
#  ('wetap:photo', 1),
#  ('}', 1),
#  ('url', 1),
#  ('access:horse', 1),
#  ('scvwd:SHAPE_Area', 1),
#  ('NR_STATUS', 1),
#  ('turn:backward', 1),
#  ('hookah', 1),
#  ('zoo', 1),
#  ('built', 1),
#  ('recycling:cardboard', 1),
#  ('est_width', 1),
#  ('wikidata', 1),
#  ('recommended_speed', 1),
#  ('seamark:daymark:colour_pattern', 1),
#  ('roof:levels', 1),
#  ('note:name', 1),
#  ('crossing:bell', 1),
#  ('Trunk_Diam', 1),
#  ('seamark:light:range', 1),
#  ('dogs', 1),
#  ('is_in:county', 1),
#  ('border_type', 1),
#  ('rcn', 1),
#  ('size', 1),
#  ('_Shape_Area_', 1),
#  ('Subclass', 1),
#  ('dry_clean', 1),
#  ('recycling:glass', 1),
#  ('dist:red', 1),
#  ('second_hand', 1),
#  ('sidewalk:right:kerb', 1),
#  ('maxweight', 1),
#  ('muni_route_ref', 1),
#  ('avgspeed', 1),
#  ('common', 1),
#  ('seamark:light:height', 1),
#  ('dist:white', 1),
#  ('category', 1),
#  ('mtb:scale:uphill', 1),
#  ('recycling:plastic_bottles', 1),
#  ('kerb', 1),
#  ('embankment', 1),
#  ('odbl', 1),
#  ('recycling:newspaper', 1),
#  ('name_alt', 1),
#  ('BRIDGE_NO', 1),
#  ('drive_in', 1),
#  ('attraction', 1),
#  ('gtfs_id', 1),
#  ('FMMP_land_type', 1),
#  ('postmile', 1),
#  ('crossing:light', 1),
#  ('land_type', 1),
#  ('path_type', 1),
#  ('noaa:taghash', 1),
#  ('addr:7:housenumber', 1),
#  ('nps:type', 1),
#  ('note:highway', 1),
#  ('verified:name', 1),
#  ('male', 1),
#  ('noref', 1),
#  ('addr:inclusion', 1),
#  ('ship:type', 1),
#  ('building:min_level', 1),
#  ('source:outline', 1),
#  ('train', 1),
#  ('capacity:women', 1),
#  ('tower:construction', 1),
#  ('separated', 1),
#  ('mrosd:name_2', 1),
#  ('type', 1),
#  ('wetap:temperature', 1),
#  ('scvwd:POND_NUM', 1),
#  ('tower:type', 1),
#  ('handrail', 1),
#  ('payment:dogecoin', 1),
#  ('difficulty', 1),
#  ('address', 1),
#  ('studio', 1),
#  ('source:website', 1),
#  ('toll', 1),
#  ('name:absent', 1),
#  ('field_marking', 1),
#  ('clothes', 1),
#  ('recycling:paper', 1),
#  ('subway', 1),
#  ('name:zh', 1),
#  ('addr.source:housenumber', 1),
#  ('recycling:magazines', 1),
#  ('icao', 1),
#  ('psv', 1),
#  ('addr:6:housenumber', 1),
#  ('health_facility:type', 1)]

# %% [markdown]
# # Audit Addresses

# %%
expected = ["Alley", "Avenue", "Boulevard", "Center", "Circle", "Common", "Commons", 
            "Corte", "Court", "Courtyard", "Drive", "Expressway", 
            "Highway", "Lane", "Loop", "Mall", "Path", "Park", "Parkway", "Place", "Plaza",
            "Real", "Road", "Square", "Street", "Terrace", "Trail", "Walk",
            "Way"]

mapping = { "Aly": "Alley",
            "AVE": "Avenue",
            "Ave": "Avenue",
            "Aveenue": "Avenue",
            "Avenie": "Avenue",
            "Ave.": "Avenue",
            "blvd": "Boulevard",
            "BLVD.": "Boulevard",
            "BLVD": "Boulevard",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Boulvevard": "Boulevard",
            "Boulevar": "Boulevard",
            "Cir": "Circle",
            "Circle:": "Circle",
            "court": "Court",
            "Ct": "Court",
            "Ct.": "Court",
            "Ctr": "Center",
            "Dr": "Drive",
            "Expwy": "Expressway",
            "Hwy": "Highway",
            "Hwy.": "Highway",
            "Ln": "Lane",
            "Ln.": "Lane",
            "parkway": "Parkway",
            "PKWY": "Parkway",
            "PL": "Place",
            "Pl": "Place",
            "PT": "Point",
            "road": "Road",
            "Rd": "Road",
            "Rd.": "Road",
            "st": "Street",
            "St": "Street",
            "St.": "Street",
            "street": "Street",
            "terrace": "Terrace",
            "way": "Way",
            "WAy": "Way"
            }

# %%
def audit_street_type_regex(street_types, regex, street_name):
    # Assume group(1) contains the street type
    m = regex.search(street_name)
    if m:
        street_type = m.group(1)
        if street_type not in expected and street_type not in mapping:
            street_types[street_type].add(street_name)

def audit_street_type(street_types, street_name):
    audit_street_type_regex(street_types, street_type_re, street_name)
    audit_street_type_regex(street_types, street_type_num_re, street_name)
    
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def is_postcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def is_county(elem):
    return (elem.attrib['k'] == "addr:county")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    postcodes = defaultdict(int)
    counties = defaultdict(int)
    
    for i, elem in enumerate(get_element(osm_file)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                k = tag.attrib['k']
                v = tag.attrib['v']
                
                if is_street_name(tag):
                    audit_street_type(street_types, v)
                
                if is_postcode(tag):
                    postcodes[v] += 1
                    
                if is_county(tag):
                    counties[v] += 1
                    
    osm_file.close()
    return street_types, postcodes, counties


def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        new_street_type = mapping[street_type]
        name = re.sub(street_type_re, new_street_type, name)
    return name

# %%
street_types, post_codes, counties = audit(OSM_FILE)

# %%
street_types
# Out:
# defaultdict(set,
#             {'100': {'Northgate Blvd #100'},
#              '140': {'West Highway 140'},
#              '2': {'Showers Drive STE 2'},
#              '88': {'East State Route 88'},
#              'Alameda': {'Alameda'},
#              'Axis': {'North-South Axis'},
#              'Barcelona': {'Calle de Barcelona'},
#              'Broadway': {'Broadway'},
#              'Bruno': {'Serra San Bruno'},
#              'Cay': {'Cavalla Cay'},
#              'D': {'El Camino Real #D'},
#              'East': {'Park Circle East'},
#              'H': {'Avenue H'},
#              'Key': {'Montego Key'},
#              'Lagoon': {'Del Oro Lagoon'},
#              'PZ': {'Portage PZ'},
#              'PlaceZ': {'Town Center PlaceZ'},
#              'Presada': {'Paseo Presada'},
#              'Reef': {'Bahama Reef'},
#              'Route': {'East State Route 88'},
#              'Row': {'Alvarado Row'},
#              'STE': {'Showers Drive STE 2'},
#              'Verda': {'Valle Verda'},
#              'Village': {'Town and Country Village'},
#              'Vista': {'Villa Vista'},
#              'West': {'Francisco Boulevard West'}})

# %%
[k for k in post_codes if len(k) > 10]
# Out:
# ['1 Donner St, San Juan Bautista, CA 95045']

# %%
counties
# Out:
# defaultdict(int,
#             {'Alameda': 5,
#              'Contra Costa': 7,
#              'Marin': 8,
#              'Merced': 1,
#              'Monterey': 2,
#              'Napa': 4,
#              'Sacramento': 11,
#              'San Benito': 1,
#              'San Benito County': 67,
#              'San Joaquin': 13,
#              'San Mateo': 2,
#              'Santa Clara': 15,
#              'Solano': 8,
#              'Sonoma': 1,
#              'Stanislaus': 2,
#              'Yolo': 9})

# %% [markdown]
# # Cleaning

# %%
def update_street_name_regex(regex, name, mapping):
    m = regex.search(name)
    if m:
        street_type = m.group(1)
        new_street_type = mapping.get(street_type)
        if new_street_type:
            name = re.sub(regex, new_street_type, name)
            return name
    
    return name

def update_street_name(name, mapping):
    new_name = update_street_name_regex(street_type_re, name, mapping)
    if new_name != name:
        return new_name
    
    new_name = update_street_name_regex(street_type_num_re, name, mapping)
    if new_name != name:
        return new_name
    
    return name

postcode_re = re.compile(r'[0-9]{5,5}$', re.IGNORECASE)
postcode_dash_re = re.compile(r'[0-9]{5,5}-[0-9]{4,4}$', re.IGNORECASE)

def has_valid_postcode(name):
    return postcode_re.search(name) is not None or postcode_dash_re.search(name) is not None

def update_postcode(name):
    m = postcode_re.search(name)
    if m is None:
        m = postcode_dash_re.search(name)
    return m.group()

# %%
postcode1 = "94588"
postcode2 = "94588-1234"
address = "1 Donner St, San Juan Bautista, CA 95045"
address2 = "950 San Felipe Rd, San Benito County, CA, -"

postcode_re = re.compile(r'[0-9]{5,5}$', re.IGNORECASE)
postcode_dash_re = re.compile(r'[0-9]{5,5}-[0-9]{4,4}$', re.IGNORECASE)
#postcode_re = re.compile(r'(\b\S+\.?)(?= #?[0-9]+$)', re.IGNORECASE)

# %%
postcode_re.search(postcode1).group()
# Out:
# '94588'

# %%
postcode_dash_re.search(postcode2).group()
# Out:
# '94588-1234'

# %%
postcode_re.search(address).group() and len(address) > 5
# Out:
# '95045'

# %%
display(has_valid_postcode(postcode1))
display(has_valid_postcode(postcode2))
display(has_valid_postcode(address))
display(has_valid_postcode(address2))
# Out:
# True
# True
# True
# False

# %%
m = postcode_re.search(address)
m

# %%
update_postcode(address)
# Out:
# '95045'

# %%
display(update_street_name("2nd st", mapping))
display(update_street_name("Northgate Blvd #100", mapping))
# Out:
# '2nd Street'
# 'Northgate Boulevard #100'

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = ["version", "changeset", "timestamp", "user", "uid"]
POSITION = ["lat", "lon"]

def has_lat_lon(element):
    return 'lat' in element.attrib and 'lon' in element.attrib

def shape_attributes(element, node):
    for attr in element.attrib:
        if attr in CREATED or attr in POSITION:
            continue
        node[attr] = element.attrib[attr]
        #print attr, element.attrib[attr]
    
    created = {}
    for attr in CREATED:
        if attr in element.attrib:
            created[attr] = element.attrib[attr]
    node['created'] = created
    
    if has_lat_lon(element):
        node['pos'] = [float(element.attrib['lat']), float(element.attrib['lon'])]

def shape_tags(element, node):
    address = {}
    for tag in element.iter("tag"):
        key = tag.attrib['k']
        value = tag.attrib['v']
        
        if is_street_name(tag):
            value = update_street_name(value, mapping)
        
        if is_postcode(tag):
            if not has_valid_postcode(value):
                continue
            value = update_postcode(value)
                    
        #print key, value
        if (re.search(problemchars, key) or 
            (re.search(lower, key) is None and 
            re.search(lower_colon, key) is None)):
            continue
        
        if re.search(lower_colon, key):
            key_arr = key.split(':')
            prefix = key_arr[0]
            suffix = key_arr[1]
            
            if prefix == 'addr':
                address[suffix] = value
            else:
                key = re.sub(':', "-", key)
                node[key] = value
                
            continue
        
        node[key] = value
    
    if len(address) > 0:
        #print node
        node['address'] = address    

def shape_node_refs(element, way):
    refs = []
    if element.tag == "way":
        for nd in element.iter("nd"):
            refs.append(nd.attrib['ref'])
        way['node_refs'] = refs
    
def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        # Handle top-level element
        node['type'] = element.tag
        
        shape_attributes(element, node)   
        
        # Handle tags
        shape_tags(element, node)
        
        # Handle node refs for way
        shape_node_refs(element, node)
        
        #print node
        return node
    else:
        return None

# %%
def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %%
process_map(OSM_FILE, True)
# Out:
# [{'created': {'changeset': '22950379',
#    'timestamp': '2014-06-15T18:55:15Z',
#    'uid': '1660455',
#    'user': 'juergenb22',
#    'version': '6'},
#   'id': '281266',
#   'pos': [37.5601845, -122.3025783],
#   'type': 'node'},
#  {'created': {'changeset': '6777070',
#    'timestamp': '2010-12-27T12:28:53Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '18'},
#   'id': '26027702',
#   'pos': [37.3673202, -122.0315503],
#   'type': 'node'},
#  {'created': {'changeset': '26582399',
#    'timestamp': '2014-11-05T22:50:24Z',
#    'uid': '318696',
#    'user': 'n76',
#    'version': '22'},
#   'id': '26029621',
#   'pos': [37.3703601, -122.042248],
#   'type': 'node'},
#  {'created': {'changeset': '16795110',
#    'timestamp': '2013-07-02T17:40:18Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '4'},
#   'id': '26050461',
#   'pos': [37.4086331, -122.1069576],
#   'type': 'node'},
#  {'created': {'changeset': '26243141',
#    'timestamp': '2014-10-21T21:10:13Z',
#    'uid': '595221',
#    'user': 'matthieun',
#    'version': '5'},
#   'id': '26391753',
#   'pos': [37.411656, -122.0538658],
#   'type': 'node'},
#  {'created': {'changeset': '231509',
#    'timestamp': '2007-03-08T02:41:19Z',
#    'uid': '999',
#    'user': 'mikelmaron',
#    'version': '1'},
#   'id': '26408766',
#   'pos': [37.4261387, -122.0515497],
#   'type': 'node'},
#  {'created': {'changeset': '4507954',
#    'timestamp': '2010-04-23T22:01:42Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '24'},
#   'id': '26497351',
#   'pos': [37.3340488, -122.0472589],
#   'type': 'node'},
#  {'created': {'changeset': '6943830',
#    'timestamp': '2011-01-12T04:05:08Z',
#    'uid': '201724',
#    'user': 'mk408',
#    'version': '42'},
#   'id': '26506901',
#   'pos': [37.1708556, -121.9902223],
#   'type': 'node'},
#  {'created': {'changeset': '1291381',
#    'timestamp': '2009-05-23T03:30:41Z',
#    'uid': '55774',
#    'user': 'nmixter',
#    'version': '13'},
#   'id': '26507066',
#   'pos': [37.0201961, -122.0272343],
#   'type': 'node'},
#  {'created': {'changeset': '705935',
#    'timestamp': '2008-01-28T10:55:00Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '26819601',
#   'pos': [37.9578554, -122.330712],
#   'type': 'node'},
#  {'created': {'changeset': '4358632',
#    'timestamp': '2010-04-07T20:11:19Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '2'},
#   'id': '29523969',
#   'pos': [37.4148475, -122.0618857],
#   'type': 'node'},
#  {'created': {'changeset': '74256',
#    'timestamp': '2009-04-02T07:39:01Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '8'},
#   'id': '29892655',
#   'pos': [37.8622935, -122.5055743],
#   'type': 'node'},
#  {'created': {'changeset': '4701479',
#    'timestamp': '2010-05-15T00:12:30Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '13'},
#   'id': '30029461',
#   'pos': [37.698579, -121.9323682],
#   'type': 'node'},
#  {'created': {'changeset': '462576',
#    'timestamp': '2009-02-15T12:49:31Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '7'},
#   'id': '30033780',
#   'pos': [38.0346451, -122.537098],
#   'type': 'node'},
#  {'created': {'changeset': '488985',
#    'timestamp': '2009-02-16T05:41:59Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '60'},
#   'id': '30033895',
#   'pos': [38.7053989, -122.9070861],
#   'type': 'node'},
#  {'created': {'changeset': '4507954',
#    'timestamp': '2010-04-23T21:59:00Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '25'},
#   'id': '30237217',
#   'pos': [37.3321379, -122.0588299],
#   'type': 'node'},
#  {'created': {'changeset': '16981620',
#    'timestamp': '2013-07-17T02:14:03Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '7'},
#   'id': '30366110',
#   'pos': [37.826832, -122.2859122],
#   'type': 'node'},
#  {'created': {'changeset': '36993783',
#    'timestamp': '2016-02-04T09:42:38Z',
#    'uid': '2015224',
#    'user': 'Jothirnadh',
#    'version': '19'},
#   'id': '30674486',
#   'pos': [37.3603209, -122.0975655],
#   'type': 'node'},
#  {'created': {'changeset': '7186612',
#    'timestamp': '2011-02-04T20:40:19Z',
#    'uid': '4902',
#    'user': 'mbuege',
#    'version': '5'},
#   'id': '30677586',
#   'pos': [37.7795734, -122.3890803],
#   'type': 'node'},
#  {'created': {'changeset': '5589997',
#    'timestamp': '2010-08-25T13:51:28Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '33'},
#   'id': '30677937',
#   'pos': [37.5006661, -122.3213109],
#   'type': 'node'},
#  {'created': {'changeset': '8197574',
#    'timestamp': '2011-05-20T10:55:28Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '38'},
#   'id': '31053103',
#   'pos': [37.4757159, -122.2989884],
#   'type': 'node'},
#  {'created': {'changeset': '754183',
#    'timestamp': '2008-11-16T01:50:24Z',
#    'uid': '54598',
#    'user': 'adbrown',
#    'version': '49'},
#   'id': '31354467',
#   'pos': [37.2443247, -121.8232651],
#   'type': 'node'},
#  {'created': {'changeset': '1658707',
#    'timestamp': '2009-06-28T06:41:00Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '2'},
#   'id': '31652108',
#   'pos': [37.8253146, -122.3124393],
#   'type': 'node'},
#  {'created': {'changeset': '870226',
#    'timestamp': '2009-03-30T11:14:29Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '5'},
#   'id': '31789063',
#   'pos': [37.8337768, -122.2952954],
#   'type': 'node'},
#  {'created': {'changeset': '12302635',
#    'timestamp': '2012-07-19T00:42:14Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31791695',
#   'pos': [38.1630245, -122.4207339],
#   'type': 'node'},
#  {'created': {'changeset': '14617259',
#    'timestamp': '2013-01-12T00:23:21Z',
#    'uid': '635896',
#    'user': 'bigwebguy',
#    'version': '5'},
#   'id': '31794797',
#   'pos': [37.5439981, -122.0883714],
#   'type': 'node'},
#  {'created': {'changeset': '12297016',
#    'timestamp': '2012-07-18T20:24:35Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31796452',
#   'pos': [37.8881044, -122.5109394],
#   'type': 'node'},
#  {'created': {'changeset': '12290233',
#    'timestamp': '2012-07-18T17:15:16Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31798358',
#   'pos': [37.5513863, -122.2478082],
#   'type': 'node'},
#  {'created': {'changeset': '12302143',
#    'timestamp': '2012-07-19T00:10:48Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31800638',
#   'pos': [38.1349536, -122.0855955],
#   'type': 'node'},
#  {'created': {'changeset': '12297016',
#    'timestamp': '2012-07-18T20:24:38Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31804083',
#   'pos': [37.9305341, -122.5048827],
#   'type': 'node'},
#  {'created': {'changeset': '12302244',
#    'timestamp': '2012-07-19T00:19:47Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31809641',
#   'pos': [38.0432257, -122.1536593],
#   'type': 'node'},
#  {'created': {'changeset': '12302779',
#    'timestamp': '2012-07-19T00:52:52Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31812358',
#   'pos': [38.1571012, -122.5485379],
#   'type': 'node'},
#  {'created': {'changeset': '12290233',
#    'timestamp': '2012-07-18T17:15:10Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31815950',
#   'pos': [37.5092568, -122.2439042],
#   'type': 'node'},
#  {'created': {'changeset': '15865774',
#    'timestamp': '2013-04-25T21:14:18Z',
#    'uid': '153669',
#    'user': 'dchiles',
#    'version': '2'},
#   'id': '31817516',
#   'pos': [37.8956666, -122.3112884],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '12302191',
#    'timestamp': '2012-07-19T00:16:04Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31819496',
#   'pos': [38.0432433, -122.0930056],
#   'type': 'node'},
#  {'created': {'changeset': '12290799',
#    'timestamp': '2012-07-18T17:36:27Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31820732',
#   'pos': [37.8071678, -122.3619472],
#   'type': 'node'},
#  {'created': {'changeset': '12289746',
#    'timestamp': '2012-07-18T16:59:28Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31821544',
#   'pos': [37.5253916, -122.0996089],
#   'type': 'node'},
#  {'created': {'changeset': '12302191',
#    'timestamp': '2012-07-19T00:16:05Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31822712',
#   'pos': [38.0550296, -122.1236103],
#   'type': 'node'},
#  {'created': {'changeset': '12290510',
#    'timestamp': '2012-07-18T17:26:26Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31824459',
#   'pos': [37.8938604, -122.3512767],
#   'type': 'node'},
#  {'created': {'changeset': '12296699',
#    'timestamp': '2012-07-18T20:16:27Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31825131',
#   'pos': [37.4023641, -122.4260415],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#    'timestamp': '2012-07-18T18:38:06Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31826495',
#   'pos': [37.6655098, -122.3882527],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#    'timestamp': '2012-07-18T18:38:00Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31827027',
#   'pos': [37.6439306, -122.3908698],
#   'type': 'node'},
#  {'created': {'changeset': '12301260',
#    'timestamp': '2012-07-18T23:02:53Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31827923',
#   'pos': [37.4801669, -121.9984419],
#   'type': 'node'},
#  {'created': {'changeset': '12302161',
#    'timestamp': '2012-07-19T00:12:52Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31828453',
#   'pos': [38.0557798, -122.0385677],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#    'timestamp': '2012-07-18T18:38:14Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31829013',
#   'pos': [37.7012798, -122.3929734],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#    'timestamp': '2012-07-18T18:38:20Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31829534',
#   'pos': [37.7470067, -122.3796174],
#   'type': 'node'},
#  {'created': {'changeset': '12291860',
#    'timestamp': '2012-07-18T18:15:46Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31830125',
#   'pos': [37.7340502, -122.2542372],
#   'type': 'node'},
#  {'created': {'changeset': '16131384',
#    'timestamp': '2013-05-14T21:05:45Z',
#    'uid': '116769',
#    'user': 'probabble',
#    'version': '3'},
#   'id': '31830618',
#   'pos': [37.8913479, -122.3236848],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '12290233',
#    'timestamp': '2012-07-18T17:15:18Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '6'},
#   'id': '31831255',
#   'pos': [37.5643864, -122.2498377],
#   'type': 'node'},
#  {'created': {'changeset': '12290912',
#    'timestamp': '2012-07-18T17:39:41Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31831727',
#   'pos': [37.962927, -122.4193299],
#   'type': 'node'},
#  {'created': {'changeset': '12291003',
#    'timestamp': '2012-07-18T17:43:38Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '6'},
#   'id': '31832324',
#   'pos': [37.9404381, -122.4842582],
#   'type': 'node'},
#  {'created': {'changeset': '12291003',
#    'timestamp': '2012-07-18T17:43:31Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31833012',
#   'pos': [37.8937481, -122.4948765],
#   'type': 'node'},
#  {'created': {'changeset': '12290233',
#    'timestamp': '2012-07-18T17:15:08Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '8'},
#   'id': '31833575',
#   'pos': [37.5055973, -122.2123112],
#   'type': 'node'},
#  {'created': {'changeset': '12302143',
#    'timestamp': '2012-07-19T00:10:48Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31834149',
#   'pos': [38.1274258, -122.1003069],
#   'type': 'node'},
#  {'created': {'changeset': '12302143',
#    'timestamp': '2012-07-19T00:10:51Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31834664',
#   'pos': [38.1396313, -122.0950385],
#   'type': 'node'},
#  {'created': {'changeset': '12302063',
#    'timestamp': '2012-07-19T00:05:22Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31835382',
#   'pos': [38.201115, -122.0308391],
#   'type': 'node'},
#  {'created': {'changeset': '12302779',
#    'timestamp': '2012-07-19T00:52:57Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31835933',
#   'pos': [38.1756045, -122.5350705],
#   'type': 'node'},
#  {'created': {'changeset': '12302635',
#    'timestamp': '2012-07-19T00:42:13Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31836512',
#   'pos': [38.1616073, -122.4203305],
#   'type': 'node'},
#  {'created': {'changeset': '12290233',
#    'timestamp': '2012-07-18T17:15:14Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31837070',
#   'pos': [37.5255048, -122.2466569],
#   'type': 'node'},
#  {'created': {'changeset': '12290233',
#    'timestamp': '2012-07-18T17:15:10Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31837677',
#   'pos': [37.5094545, -122.193645],
#   'type': 'node'},
#  {'created': {'changeset': '12302308',
#    'timestamp': '2012-07-19T00:26:34Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31838150',
#   'pos': [38.1289192, -122.3062652],
#   'type': 'node'},
#  {'created': {'changeset': '12290631',
#    'timestamp': '2012-07-18T17:31:31Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31838688',
#   'pos': [37.767472, -122.2917181],
#   'type': 'node'},
#  {'created': {'changeset': '12290510',
#    'timestamp': '2012-07-18T17:26:38Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31839372',
#   'pos': [37.9801475, -122.3686171],
#   'type': 'node'},
#  {'created': {'changeset': '12302779',
#    'timestamp': '2012-07-19T00:53:01Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31840593',
#   'pos': [38.1993667, -122.5488113],
#   'type': 'node'},
#  {'created': {'changeset': '19351224',
#    'timestamp': '2013-12-09T01:59:20Z',
#    'uid': '153669',
#    'user': 'dchiles',
#    'version': '4'},
#   'id': '31841085',
#   'pos': [37.8554769, -122.4392552],
#   'type': 'node'},
#  {'created': {'changeset': '12291412',
#    'timestamp': '2012-07-18T18:01:54Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31841612',
#   'pos': [37.8260932, -122.4784866],
#   'type': 'node'},
#  {'created': {'changeset': '12297372',
#    'timestamp': '2012-07-18T20:32:28Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31842233',
#   'pos': [37.7850746, -122.5095662],
#   'type': 'node'},
#  {'created': {'changeset': '12289485',
#    'timestamp': '2012-07-18T16:48:33Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31842616',
#   'pos': [37.7796204, -122.2437381],
#   'type': 'node'},
#  {'created': {'changeset': '12302440',
#    'timestamp': '2012-07-19T00:31:53Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31843216',
#   'pos': [38.0223919, -122.2895369],
#   'type': 'node'},
#  {'created': {'changeset': '12289485',
#    'timestamp': '2012-07-18T16:48:29Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31843792',
#   'pos': [37.7551251, -122.2152088],
#   'type': 'node'},
#  {'created': {'changeset': '12302440',
#    'timestamp': '2012-07-19T00:32:08Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31844279',
#   'pos': [38.1229665, -122.2961315],
#   'type': 'node'},
#  {'created': {'changeset': '14617259',
#    'timestamp': '2013-01-12T00:23:25Z',
#    'uid': '635896',
#    'user': 'bigwebguy',
#    'version': '5'},
#   'id': '31844887',
#   'pos': [37.536655, -122.0795226],
#   'type': 'node'},
#  {'created': {'changeset': '12302071',
#    'timestamp': '2012-07-19T00:05:39Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31845445',
#   'pos': [38.2330015, -122.0279073],
#   'type': 'node'},
#  {'created': {'changeset': '12291003',
#    'timestamp': '2012-07-18T17:43:45Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31845993',
#   'pos': [37.9821391, -122.4639657],
#   'type': 'node'},
#  {'created': {'changeset': '12298121',
#    'timestamp': '2012-07-18T20:55:04Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31846550',
#   'pos': [38.4424757, -123.0702028],
#   'type': 'node'},
#  {'created': {'changeset': '12290233',
#    'timestamp': '2012-07-18T17:15:15Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31847159',
#   'pos': [37.5340563, -122.2335959],
#   'type': 'node'},
#  {'created': {'changeset': '12302071',
#    'timestamp': '2012-07-19T00:05:41Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31847748',
#   'pos': [38.2409366, -122.0401326],
#   'type': 'node'},
#  {'created': {'changeset': '12290912',
#    'timestamp': '2012-07-18T17:39:32Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31848402',
#   'pos': [37.9225682, -122.390991],
#   'type': 'node'},
#  {'created': {'changeset': '12302191',
#    'timestamp': '2012-07-19T00:15:59Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31849191',
#   'pos': [38.0318824, -122.0812763],
#   'type': 'node'},
#  {'created': {'changeset': '29113053',
#    'timestamp': '2015-02-26T14:19:20Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '31849692',
#   'pos': [37.7652338, -122.2244993],
#   'type': 'node'},
#  {'created': {'changeset': '12298121',
#    'timestamp': '2012-07-18T20:55:05Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31850369',
#   'pos': [38.4428723, -123.0666837],
#   'type': 'node'},
#  {'created': {'changeset': '12302191',
#    'timestamp': '2012-07-19T00:16:03Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31851015',
#   'pos': [38.0426573, -122.0985009],
#   'type': 'node'},
#  {'created': {'changeset': '12289485',
#    'timestamp': '2012-07-18T16:48:31Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31852355',
#   'pos': [37.7642933, -122.2255583],
#   'type': 'node'},
#  {'created': {'changeset': '12302063',
#    'timestamp': '2012-07-19T00:05:33Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31853560',
#   'pos': [38.2263582, -122.0334435],
#   'type': 'node'},
#  {'created': {'changeset': '12291887',
#    'timestamp': '2012-07-18T18:16:20Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31854578',
#   'pos': [37.7376142, -122.3749841],
#   'type': 'node'},
#  {'created': {'changeset': '12298121',
#    'timestamp': '2012-07-18T20:55:06Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31855638',
#   'pos': [38.4436589, -123.0649757],
#   'type': 'node'},
#  {'created': {'changeset': '12302063',
#    'timestamp': '2012-07-19T00:05:12Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31856650',
#   'pos': [38.1795984, -122.0187822],
#   'type': 'node'},
#  {'created': {'changeset': '12291003',
#    'timestamp': '2012-07-18T17:43:45Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31857212',
#   'pos': [37.9812111, -122.4737593],
#   'type': 'node'},
#  {'created': {'changeset': '12291003',
#    'timestamp': '2012-07-18T17:43:29Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31857748',
#   'pos': [37.8865748, -122.4752642],
#   'type': 'node'},
#  {'created': {'changeset': '36769131',
#    'timestamp': '2016-01-24T02:45:09Z',
#    'uid': '46789',
#    'user': 'jraller',
#    'version': '5'},
#   'id': '31858197',
#   'pos': [37.7678425, -122.2858423],
#   'type': 'node'},
#  {'created': {'changeset': '12291161',
#    'timestamp': '2012-07-18T17:50:59Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31858692',
#   'pos': [37.8538624, -122.4355038],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#    'timestamp': '2012-07-18T18:38:02Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31859297',
#   'pos': [37.6498949, -122.3798843],
#   'type': 'node'},
#  {'created': {'changeset': '12302063',
#    'timestamp': '2012-07-19T00:05:29Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31859815',
#   'pos': [38.2244163, -122.0072737],
#   'type': 'node'},
#  {'created': {'changeset': '12289746',
#    'timestamp': '2012-07-18T16:59:28Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31860380',
#   'pos': [37.5221662, -122.1031127],
#   'type': 'node'},
#  {'created': {'changeset': '12302063',
#    'timestamp': '2012-07-19T00:05:33Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31861006',
#   'pos': [38.2262706, -122.0053683],
#   'type': 'node'},
#  {'created': {'changeset': '14617259',
#    'timestamp': '2013-01-12T00:23:27Z',
#    'uid': '635896',
#    'user': 'bigwebguy',
#    'version': '4'},
#   'id': '31861515',
#   'pos': [37.560739, -122.1086926],
#   'type': 'node'},
#  {'created': {'changeset': '12302161',
#    'timestamp': '2012-07-19T00:12:50Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31862304',
#   'pos': [38.0479967, -122.0578358],
#   'type': 'node'},
#  {'created': {'changeset': '12291412',
#    'timestamp': '2012-07-18T18:02:00Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31863125',
#   'pos': [37.8597547, -122.4437553],
#   'type': 'node'},
#  {'created': {'changeset': '20304972',
#    'timestamp': '2014-01-31T18:50:33Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '5'},
#   'id': '31863940',
#   'pos': [38.0720495, -122.2410584],
#   'type': 'node'},
#  {'created': {'changeset': '12292084',
#    'timestamp': '2012-07-18T18:20:49Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31864675',
#   'pos': [37.5670397, -122.2865496],
#   'type': 'node'},
#  {'created': {'changeset': '12291003',
#    'timestamp': '2012-07-18T17:43:32Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31865597',
#   'pos': [37.8948582, -122.4595367],
#   'type': 'node'},
#  {'created': {'changeset': '12292969',
#    'timestamp': '2012-07-18T18:38:02Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31867047',
#   'pos': [37.6568466, -122.3767592],
#   'type': 'node'},
#  {'created': {'changeset': '12292084',
#    'timestamp': '2012-07-18T18:20:51Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31868571',
#   'pos': [37.5694365, -122.292388],
#   'type': 'node'},
#  {'created': {'changeset': '12290912',
#    'timestamp': '2012-07-18T17:39:31Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '8'},
#   'id': '31869249',
#   'pos': [37.9091924, -122.3770901],
#   'type': 'node'},
#  {'created': {'changeset': '12302635',
#    'timestamp': '2012-07-19T00:42:21Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31869809',
#   'pos': [38.1980812, -122.3922467],
#   'type': 'node'},
#  {'created': {'changeset': '12302779',
#    'timestamp': '2012-07-19T00:53:01Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31871085',
#   'pos': [38.1979887, -122.561987],
#   'type': 'node'},
#  {'created': {'changeset': '12302779',
#    'timestamp': '2012-07-19T00:52:53Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31873650',
#   'pos': [38.1618927, -122.544366],
#   'type': 'node'},
#  {'created': {'changeset': '12298380',
#    'timestamp': '2012-07-18T21:02:18Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31929920',
#   'pos': [37.9824133, -121.4730695],
#   'type': 'node'},
#  {'created': {'changeset': '12304879',
#    'timestamp': '2012-07-19T02:16:55Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31939627',
#   'pos': [38.0089236, -121.6185645],
#   'type': 'node'},
#  {'created': {'changeset': '12298967',
#    'timestamp': '2012-07-18T21:20:18Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31949557',
#   'pos': [37.9605066, -121.5674629],
#   'type': 'node'},
#  {'created': {'changeset': '43576898',
#    'timestamp': '2016-11-12T08:52:08Z',
#    'uid': '402624',
#    'user': 'bdiscoe',
#    'version': '4'},
#   'id': '31952282',
#   'pos': [37.915263, -121.3226226],
#   'type': 'node'},
#  {'created': {'changeset': '12305038',
#    'timestamp': '2012-07-19T02:24:29Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31954199',
#   'pos': [38.0462788, -121.6534741],
#   'type': 'node'},
#  {'created': {'changeset': '12304718',
#    'timestamp': '2012-07-19T02:06:12Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31954854',
#   'pos': [38.1691496, -121.530149],
#   'type': 'node'},
#  {'created': {'changeset': '12304784',
#    'timestamp': '2012-07-19T02:11:35Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31955896',
#   'pos': [38.0289806, -121.5007615],
#   'type': 'node'},
#  {'created': {'changeset': '12298958',
#    'timestamp': '2012-07-18T21:20:10Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31956524',
#   'pos': [37.9152919, -121.5659607],
#   'type': 'node'},
#  {'created': {'changeset': '12298077',
#    'timestamp': '2012-07-18T20:54:20Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31956998',
#   'pos': [37.9614355, -121.3640642],
#   'type': 'node'},
#  {'created': {'changeset': '12298284',
#    'timestamp': '2012-07-18T20:59:42Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31957508',
#   'pos': [37.9988347, -121.4049488],
#   'type': 'node'},
#  {'created': {'changeset': '12303825',
#    'timestamp': '2012-07-19T01:27:24Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31958293',
#   'pos': [38.2027068, -121.4783209],
#   'type': 'node'},
#  {'created': {'changeset': '12304795',
#    'timestamp': '2012-07-19T02:12:09Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31958866',
#   'pos': [38.1092653, -121.5001165],
#   'type': 'node'},
#  {'created': {'changeset': '12305203',
#    'timestamp': '2012-07-19T02:30:56Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31959684',
#   'pos': [38.0398209, -121.8070655],
#   'type': 'node'},
#  {'created': {'changeset': '12298832',
#    'timestamp': '2012-07-18T21:15:07Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31960678',
#   'pos': [37.9404711, -121.5598522],
#   'type': 'node'},
#  {'created': {'changeset': '12298284',
#    'timestamp': '2012-07-18T20:59:37Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31961139',
#   'pos': [37.9962361, -121.4112107],
#   'type': 'node'},
#  {'created': {'changeset': '12304718',
#    'timestamp': '2012-07-19T02:06:10Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31961768',
#   'pos': [38.1580623, -121.5023054],
#   'type': 'node'},
#  {'created': {'changeset': '12303991',
#    'timestamp': '2012-07-19T01:35:40Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31962280',
#   'pos': [38.1062591, -121.4988482],
#   'type': 'node'},
#  {'created': {'changeset': '12305038',
#    'timestamp': '2012-07-19T02:24:34Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31962859',
#   'pos': [38.0788346, -121.6769202],
#   'type': 'node'},
#  {'created': {'changeset': '31833357',
#    'timestamp': '2015-06-09T04:34:16Z',
#    'uid': '734',
#    'user': 'diggernet',
#    'version': '4'},
#   'id': '31963933',
#   'pos': [38.0635443, -121.5835177],
#   'type': 'node'},
#  {'created': {'changeset': '12303884',
#    'timestamp': '2012-07-19T01:30:35Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31964426',
#   'pos': [38.0455458, -121.4020169],
#   'type': 'node'},
#  {'created': {'changeset': '12304885',
#    'timestamp': '2012-07-19T02:17:21Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31964959',
#   'pos': [38.1031288, -121.5661176],
#   'type': 'node'},
#  {'created': {'changeset': '12303825',
#    'timestamp': '2012-07-19T01:27:24Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31965558',
#   'pos': [38.2008424, -121.4762709],
#   'type': 'node'},
#  {'created': {'changeset': '43570645',
#    'timestamp': '2016-11-11T21:37:49Z',
#    'uid': '402624',
#    'user': 'bdiscoe',
#    'version': '5'},
#   'id': '31966069',
#   'pos': [37.9974436, -121.3671604],
#   'type': 'node'},
#  {'created': {'changeset': '12298958',
#    'timestamp': '2012-07-18T21:20:00Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31967158',
#   'pos': [37.9043643, -121.5911666],
#   'type': 'node'},
#  {'created': {'changeset': '12299283',
#    'timestamp': '2012-07-18T21:32:31Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31967636',
#   'pos': [37.8267259, -121.5943077],
#   'type': 'node'},
#  {'created': {'changeset': '12304879',
#    'timestamp': '2012-07-19T02:17:10Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31968160',
#   'pos': [38.0701459, -121.573175],
#   'type': 'node'},
#  {'created': {'changeset': '12305228',
#    'timestamp': '2012-07-19T02:33:08Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31968645',
#   'pos': [38.0269654, -121.8466905],
#   'type': 'node'},
#  {'created': {'changeset': '12298380',
#    'timestamp': '2012-07-18T21:02:13Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31969264',
#   'pos': [37.9649917, -121.4729574],
#   'type': 'node'},
#  {'created': {'changeset': '12303884',
#    'timestamp': '2012-07-19T01:30:29Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31970020',
#   'pos': [38.0408091, -121.4354602],
#   'type': 'node'},
#  {'created': {'changeset': '12304718',
#    'timestamp': '2012-07-19T02:06:02Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31970658',
#   'pos': [38.1445047, -121.5110079],
#   'type': 'node'},
#  {'created': {'changeset': '12298479',
#    'timestamp': '2012-07-18T21:05:53Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31971488',
#   'pos': [37.8099567, -121.4150859],
#   'type': 'node'},
#  {'created': {'changeset': '12298284',
#    'timestamp': '2012-07-18T20:59:42Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31972691',
#   'pos': [37.9987986, -121.4164487],
#   'type': 'node'},
#  {'created': {'changeset': '12298077',
#    'timestamp': '2012-07-18T20:54:23Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31973384',
#   'pos': [37.9679591, -121.3569873],
#   'type': 'node'},
#  {'created': {'changeset': '12305038',
#    'timestamp': '2012-07-19T02:24:39Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31973832',
#   'pos': [38.1017027, -121.6301676],
#   'type': 'node'},
#  {'created': {'changeset': '12304784',
#    'timestamp': '2012-07-19T02:11:43Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31974394',
#   'pos': [38.0555468, -121.5226997],
#   'type': 'node'},
#  {'created': {'changeset': '12304718',
#    'timestamp': '2012-07-19T02:06:00Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31974946',
#   'pos': [38.1415238, -121.5028649],
#   'type': 'node'},
#  {'created': {'changeset': '12298284',
#    'timestamp': '2012-07-18T20:59:30Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31975532',
#   'pos': [37.9866059, -121.3917399],
#   'type': 'node'},
#  {'created': {'changeset': '12886741',
#    'timestamp': '2012-08-28T02:09:53Z',
#    'uid': '598043',
#    'user': 'kalc',
#    'version': '4'},
#   'id': '31976490',
#   'pos': [38.1177338, -121.5488479],
#   'type': 'node'},
#  {'created': {'changeset': '12305038',
#    'timestamp': '2012-07-19T02:24:39Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31976968',
#   'pos': [38.0978215, -121.6333712],
#   'type': 'node'},
#  {'created': {'changeset': '12304784',
#    'timestamp': '2012-07-19T02:11:33Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31977371',
#   'pos': [38.0242086, -121.5120995],
#   'type': 'node'},
#  {'created': {'changeset': '12305038',
#    'timestamp': '2012-07-19T02:24:24Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31977903',
#   'pos': [38.010772, -121.6726669],
#   'type': 'node'},
#  {'created': {'changeset': '12303825',
#    'timestamp': '2012-07-19T01:27:23Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31978403',
#   'pos': [38.1986959, -121.460704],
#   'type': 'node'},
#  {'created': {'changeset': '12304879',
#    'timestamp': '2012-07-19T02:17:08Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31978884',
#   'pos': [38.0553232, -121.5802883],
#   'type': 'node'},
#  {'created': {'changeset': '12303991',
#    'timestamp': '2012-07-19T01:35:41Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31979386',
#   'pos': [38.1127353, -121.4990049],
#   'type': 'node'},
#  {'created': {'changeset': '12298958',
#    'timestamp': '2012-07-18T21:20:03Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31980098',
#   'pos': [37.907806, -121.5901612],
#   'type': 'node'},
#  {'created': {'changeset': '12304807',
#    'timestamp': '2012-07-19T02:12:14Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31980547',
#   'pos': [38.1211049, -121.5618079],
#   'type': 'node'},
#  {'created': {'changeset': '12303807',
#    'timestamp': '2012-07-19T01:26:59Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31981234',
#   'pos': [38.1405824, -121.4630768],
#   'type': 'node'},
#  {'created': {'changeset': '12304718',
#    'timestamp': '2012-07-19T02:06:11Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31981676',
#   'pos': [38.1627604, -121.5323059],
#   'type': 'node'},
#  {'created': {'changeset': '12303984',
#    'timestamp': '2012-07-19T01:35:34Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31982269',
#   'pos': [38.0966554, -121.496372],
#   'type': 'node'},
#  {'created': {'changeset': '12305355',
#    'timestamp': '2012-07-19T02:38:36Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31982671',
#   'pos': [38.0429561, -121.9344762],
#   'type': 'node'},
#  {'created': {'changeset': '12305038',
#    'timestamp': '2012-07-19T02:24:36Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '6'},
#   'id': '31983324',
#   'pos': [38.0852771, -121.6361511],
#   'type': 'node'},
#  {'created': {'changeset': '12305038',
#    'timestamp': '2012-07-19T02:24:34Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31983831',
#   'pos': [38.0786034, -121.6485304],
#   'type': 'node'},
#  {'created': {'changeset': '12304879',
#    'timestamp': '2012-07-19T02:17:01Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31984762',
#   'pos': [38.0327258, -121.5699853],
#   'type': 'node'},
#  {'created': {'changeset': '12298958',
#    'timestamp': '2012-07-18T21:19:55Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31985712',
#   'pos': [37.8986533, -121.6127972],
#   'type': 'node'},
#  {'created': {'changeset': '12298284',
#    'timestamp': '2012-07-18T20:59:37Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31986799',
#   'pos': [37.9959474, -121.4136953],
#   'type': 'node'},
#  {'created': {'changeset': '12304784',
#    'timestamp': '2012-07-19T02:11:30Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31987650',
#   'pos': [38.0161155, -121.558792],
#   'type': 'node'},
#  {'created': {'changeset': '12305228',
#    'timestamp': '2012-07-19T02:33:07Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31988535',
#   'pos': [38.0251805, -121.8273443],
#   'type': 'node'},
#  {'created': {'changeset': '12303807',
#    'timestamp': '2012-07-19T01:27:15Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31990454',
#   'pos': [38.1729202, -121.4464954],
#   'type': 'node'},
#  {'created': {'changeset': '12305355',
#    'timestamp': '2012-07-19T02:38:36Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31991269',
#   'pos': [38.0435982, -121.9353431],
#   'type': 'node'},
#  {'created': {'changeset': '12298531',
#    'timestamp': '2012-07-18T21:07:40Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '31993135',
#   'pos': [37.8195824, -121.4399834],
#   'type': 'node'},
#  {'created': {'changeset': '12304718',
#    'timestamp': '2012-07-19T02:06:12Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31996200',
#   'pos': [38.1641273, -121.530594],
#   'type': 'node'},
#  {'created': {'changeset': '12298077',
#    'timestamp': '2012-07-18T20:54:24Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '31999049',
#   'pos': [37.9688793, -121.3705572],
#   'type': 'node'},
#  {'created': {'changeset': '12298380',
#    'timestamp': '2012-07-18T21:02:16Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '31999916',
#   'pos': [37.9718675, -121.478046],
#   'type': 'node'},
#  {'created': {'changeset': '12303807',
#    'timestamp': '2012-07-19T01:27:10Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32001003',
#   'pos': [38.1675465, -121.4731616],
#   'type': 'node'},
#  {'created': {'changeset': '12303977',
#    'timestamp': '2012-07-19T01:35:13Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32002113',
#   'pos': [38.0461221, -121.4705563],
#   'type': 'node'},
#  {'created': {'changeset': '12304784',
#    'timestamp': '2012-07-19T02:11:34Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32002801',
#   'pos': [38.0260198, -121.522783],
#   'type': 'node'},
#  {'created': {'changeset': '12299283',
#    'timestamp': '2012-07-18T21:32:30Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32003544',
#   'pos': [37.8250852, -121.5959213],
#   'type': 'node'},
#  {'created': {'changeset': '12298380',
#    'timestamp': '2012-07-18T21:02:16Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '32004606',
#   'pos': [37.9749133, -121.4734069],
#   'type': 'node'},
#  {'created': {'changeset': '12299170',
#    'timestamp': '2012-07-18T21:28:09Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32005589',
#   'pos': [37.8162053, -121.5542662],
#   'type': 'node'},
#  {'created': {'changeset': '12305321',
#    'timestamp': '2012-07-19T02:36:58Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32006177',
#   'pos': [38.2254884, -121.9992228],
#   'type': 'node'},
#  {'created': {'changeset': '12303884',
#    'timestamp': '2012-07-19T01:30:32Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32007394',
#   'pos': [38.0435996, -121.4182229],
#   'type': 'node'},
#  {'created': {'changeset': '12303984',
#    'timestamp': '2012-07-19T01:35:37Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '32023019',
#   'pos': [38.1014809, -121.4905631],
#   'type': 'node'},
#  {'created': {'changeset': '8637355',
#    'timestamp': '2011-07-05T09:39:59Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '4'},
#   'id': '32351603',
#   'pos': [37.4131703, -122.0771869],
#   'type': 'node'},
#  {'created': {'changeset': '19595943',
#    'timestamp': '2013-12-23T08:43:51Z',
#    'uid': '416346',
#    'user': 'Brian@Brea',
#    'version': '9'},
#   'id': '32792742',
#   'pos': [37.4905882, -121.9284884],
#   'type': 'node'},
#  {'created': {'changeset': '6875031',
#    'timestamp': '2011-01-05T19:14:29Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '6'},
#   'id': '32817051',
#   'pos': [37.4519895, -121.8934138],
#   'type': 'node'},
#  {'created': {'changeset': '16310312',
#    'timestamp': '2013-05-27T14:19:21Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '38'},
#   'id': '32915514',
#   'pos': [37.9759064, -122.0638901],
#   'type': 'node'},
#  {'created': {'changeset': '4506056',
#    'timestamp': '2010-04-23T19:00:38Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '11'},
#   'id': '32927537',
#   'pos': [37.6630305, -122.4654307],
#   'type': 'node'},
#  {'created': {'changeset': '18222413',
#    'timestamp': '2013-10-07T01:26:28Z',
#    'uid': '1727302',
#    'user': 'RiddleMeThisBatman',
#    'version': '8'},
#   'id': '33060212',
#   'pos': [37.3656196, -122.0778408],
#   'type': 'node'},
#  {'created': {'changeset': '10128894',
#    'timestamp': '2011-12-16T05:52:17Z',
#    'uid': '162110',
#    'user': 'tahongawaka',
#    'version': '3'},
#   'id': '33154395',
#   'pos': [37.6466331, -122.094257],
#   'type': 'node'},
#  {'created': {'changeset': '4802078',
#    'timestamp': '2010-05-25T10:00:35Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '2'},
#   'id': '33219827',
#   'pos': [37.6178127, -122.1514409],
#   'type': 'node'},
#  {'created': {'changeset': '865564',
#    'timestamp': '2009-03-28T08:30:43Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '8'},
#   'id': '33374031',
#   'pos': [37.3858519, -122.0506177],
#   'type': 'node'},
#  {'created': {'changeset': '33478728',
#    'timestamp': '2015-08-21T09:15:37Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '33717328',
#   'pos': [37.3896127, -121.9547195],
#   'type': 'node'},
#  {'created': {'changeset': '15865774',
#    'timestamp': '2013-04-25T21:14:39Z',
#    'uid': '153669',
#    'user': 'dchiles',
#    'version': '2'},
#   'id': '33947294',
#   'pos': [37.8705226, -122.2310448],
#   'type': 'node'},
#  {'created': {'changeset': '14842665',
#    'timestamp': '2013-01-30T01:59:55Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '10'},
#   'highway': 'traffic_signals',
#   'id': '34035919',
#   'pos': [37.4135078, -122.0781645],
#   'source': 'Bing',
#   'type': 'node'},
#  {'created': {'changeset': '18902172',
#    'timestamp': '2013-11-14T20:15:03Z',
#    'uid': '11154',
#    'user': 'beej71',
#    'version': '3'},
#   'id': '34485299',
#   'pos': [37.8645101, -122.2411558],
#   'type': 'node'},
#  {'created': {'changeset': '4868011',
#    'timestamp': '2010-05-31T21:13:47Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '3'},
#   'id': '35706242',
#   'pos': [37.8750776, -122.2237424],
#   'type': 'node'},
#  {'created': {'changeset': '4858105',
#    'timestamp': '2010-05-30T22:28:37Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '2'},
#   'id': '35706425',
#   'pos': [37.8779989, -122.2254643],
#   'type': 'node'},
#  {'created': {'changeset': '5020116',
#    'timestamp': '2010-06-18T22:59:40Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '4'},
#   'id': '35706558',
#   'pos': [37.8731409, -122.2282125],
#   'type': 'node'},
#  {'created': {'changeset': '16557532',
#    'timestamp': '2013-06-14T23:52:25Z',
#    'uid': '190493',
#    'user': 'vonvonvon',
#    'version': '6'},
#   'id': '35718948',
#   'pos': [37.8737394, -122.2208008],
#   'type': 'node'},
#  {'created': {'changeset': '251942',
#    'timestamp': '2008-12-08T03:02:15Z',
#    'uid': '25981',
#    'user': 'Michal Migurski',
#    'version': '3'},
#   'id': '35719085',
#   'pos': [37.8675746, -122.220054],
#   'type': 'node'},
#  {'created': {'changeset': '5020116',
#    'timestamp': '2010-06-18T22:43:24Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '5'},
#   'id': '35719200',
#   'pos': [37.8674039, -122.2424805],
#   'type': 'node'},
#  {'created': {'changeset': '36845828',
#    'timestamp': '2016-01-27T21:06:12Z',
#    'uid': '1829683',
#    'user': 'Luis36995',
#    'version': '14'},
#   'id': '35854831',
#   'pos': [37.3935878, -121.920923],
#   'type': 'node'},
#  {'created': {'changeset': '10773632',
#    'timestamp': '2012-02-23T22:49:16Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '19'},
#   'id': '36229295',
#   'pos': [37.5745954, -122.3081266],
#   'type': 'node'},
#  {'created': {'changeset': '6774664',
#    'timestamp': '2010-12-27T07:36:37Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '11'},
#   'id': '49067143',
#   'pos': [37.3566043, -122.0624103],
#   'type': 'node'},
#  {'created': {'changeset': '6341122',
#    'timestamp': '2010-11-11T03:53:27Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '4'},
#   'id': '51665599',
#   'pos': [37.9058332, -122.2604426],
#   'type': 'node'},
#  {'created': {'changeset': '20404702',
#    'timestamp': '2014-02-06T01:02:54Z',
#    'uid': '318696',
#    'user': 'n76',
#    'version': '19'},
#   'id': '52154589',
#   'pos': [37.2445942, -122.1094136],
#   'type': 'node'},
#  {'created': {'changeset': '2172708',
#    'timestamp': '2009-08-17T02:56:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '52978693',
#   'pos': [37.7012682, -122.0689744],
#   'type': 'node'},
#  {'created': {'changeset': '2498408',
#    'timestamp': '2009-09-16T04:59:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '52978975',
#   'pos': [37.749413, -121.600353],
#   'type': 'node'},
#  {'created': {'changeset': '2498408',
#    'timestamp': '2009-09-16T04:59:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '52979220',
#   'pos': [37.709421, -121.622722],
#   'type': 'node'},
#  {'created': {'changeset': '36940095',
#    'timestamp': '2016-02-01T16:22:43Z',
#    'uid': '1240849',
#    'user': 'ediyes',
#    'version': '3'},
#   'id': '52979432',
#   'pos': [37.7061702, -121.6431032],
#   'type': 'node'},
#  {'created': {'changeset': '8300994',
#    'timestamp': '2011-05-31T12:16:39Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '7'},
#   'id': '52979805',
#   'pos': [37.7529701, -122.153058],
#   'type': 'node'},
#  {'created': {'changeset': '2498408',
#    'timestamp': '2009-09-16T04:59:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '52980002',
#   'pos': [37.67029, -121.571038],
#   'type': 'node'},
#  {'created': {'changeset': '2498408',
#    'timestamp': '2009-09-16T04:59:33Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '52980172',
#   'pos': [37.6844179, -121.5933309],
#   'type': 'node'},
#  {'created': {'changeset': '2498408',
#    'timestamp': '2009-09-16T04:59:38Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
# ...
#    'uid': '86565',
#    'user': 'ricomundy',
#    'version': '5'},
#   'id': '55961806',
#   'pos': [38.5409361, -122.4718982],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:15:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55961983',
#   'pos': [38.411459, -122.897674],
#   'type': 'node'},
#  {'created': {'changeset': '18274077',
#    'timestamp': '2013-10-10T01:24:38Z',
#    'uid': '371121',
#    'user': 'AndrewSnow',
#    'version': '6'},
#   'id': '55962146',
#   'pos': [38.2823789, -122.3070667],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:15:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55962319',
#   'pos': [38.277285, -122.661987],
#   'type': 'node'},
#  {'created': {'changeset': '18307523',
#    'timestamp': '2013-10-12T02:24:04Z',
#    'uid': '371121',
#    'user': 'AndrewSnow',
#    'version': '5'},
#   'id': '55962435',
#   'pos': [38.5890718, -122.582692],
#   'type': 'node'},
#  {'created': {'changeset': '8776050',
#    'timestamp': '2011-07-20T08:43:32Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '5'},
#   'id': '55962538',
#   'pos': [38.2485136, -122.2744818],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:19:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55962649',
#   'pos': [38.6205469, -122.8939371],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:15:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55962776',
#   'pos': [38.631813, -123.132382],
#   'type': 'node'},
#  {'created': {'changeset': '2517390',
#    'timestamp': '2009-09-17T22:37:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55962879',
#   'pos': [38.63725, -123.168742],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:15:53Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55963093',
#   'pos': [38.618049, -123.092264],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:15:55Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55963196',
#   'pos': [38.709302, -122.905115],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T13:58:32Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55963405',
#   'pos': [38.486509, -122.470791],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T13:58:37Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55963665',
#   'pos': [38.519302, -122.4424991],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:16:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55963805',
#   'pos': [38.477648, -123.061346],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:16:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55963926',
#   'pos': [38.355389, -122.888518],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:16:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55964047',
#   'pos': [38.566412, -123.054253],
#   'type': 'node'},
#  {'created': {'changeset': '2517390',
#    'timestamp': '2009-09-17T22:37:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55964157',
#   'pos': [38.564855, -123.076324],
#   'type': 'node'},
#  {'created': {'changeset': '6535894',
#    'timestamp': '2010-12-04T10:52:37Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '4'},
#   'id': '55964266',
#   'pos': [38.2808177, -122.2596067],
#   'type': 'node'},
#  {'created': {'changeset': '2517390',
#    'timestamp': '2009-09-17T22:37:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55964528',
#   'pos': [38.643053, -123.114163],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T13:58:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '5'},
#   'id': '55964628',
#   'pos': [38.6175999, -122.4182244],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:16:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55964758',
#   'pos': [38.578589, -123.206171],
#   'type': 'node'},
#  {'created': {'changeset': '30979242',
#    'timestamp': '2015-05-11T00:44:42Z',
#    'uid': '734',
#    'user': 'diggernet',
#    'version': '5'},
#   'id': '55964890',
#   'pos': [38.6422866, -122.4197668],
#   'type': 'node'},
#  {'created': {'changeset': '32899702',
#    'timestamp': '2015-07-27T00:47:52Z',
#    'uid': '3091106',
#    'user': 'amorde',
#    'version': '4'},
#   'id': '55965011',
#   'pos': [38.3391662, -122.6893903],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:16:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55965193',
#   'pos': [38.613714, -123.133855],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:16:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55965371',
#   'pos': [38.40726, -122.940034],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T13:59:33Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55965520',
#   'pos': [38.1614309, -122.2423342],
#   'type': 'node'},
#  {'created': {'changeset': '13623455',
#    'timestamp': '2012-10-25T05:19:29Z',
#    'uid': '67236',
#    'user': 'jfire',
#    'version': '3'},
#   'id': '55965740',
#   'pos': [38.4052779, -122.7152806],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T13:59:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '55965942',
#   'pos': [38.6430451, -122.5934],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T13:59:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '55966112',
#   'pos': [38.6735606, -122.5914721],
#   'type': 'node'},
#  {'created': {'changeset': '7151515',
#    'timestamp': '2011-02-01T04:06:34Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '3'},
#   'id': '55966254',
#   'pos': [38.131886, -122.4995632],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:16:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '55966552',
#   'pos': [38.6045455, -122.8685172],
#   'type': 'node'},
#  {'created': {'changeset': '42146037',
#    'timestamp': '2016-09-14T10:32:51Z',
#    'uid': '933797',
#    'user': 'oba510',
#    'version': '4'},
#   'id': '55966709',
#   'pos': [38.1739467, -122.2645688],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T14:00:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55966840',
#   'pos': [38.2979072, -122.28091],
#   'type': 'node'},
#  {'created': {'changeset': '28223722',
#    'timestamp': '2015-01-18T05:23:25Z',
#    'uid': '86565',
#    'user': 'ricomundy',
#    'version': '3'},
#   'id': '55966966',
#   'pos': [38.480074, -123.070744],
#   'type': 'node'},
#  {'created': {'changeset': '7153259',
#    'timestamp': '2011-02-01T10:25:47Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '4'},
#   'highway': 'turning_circle',
#   'id': '55967279',
#   'pos': [38.2133462, -122.2546628],
#   'type': 'node'},
#  {'created': {'changeset': '6847598',
#    'timestamp': '2011-01-03T10:18:28Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '5'},
#   'id': '55967401',
#   'pos': [38.4311576, -122.7163394],
#   'type': 'node'},
#  {'created': {'changeset': '17462121',
#    'timestamp': '2013-08-22T21:02:12Z',
#    'uid': '91499',
#    'user': 'paulmach',
#    'version': '3'},
#   'id': '55967559',
#   'pos': [38.4063719, -122.2076153],
#   'type': 'node'},
#  {'created': {'changeset': '7151515',
#    'timestamp': '2011-02-01T04:36:25Z',
#    'uid': '24452',
#    'user': 'Speight',
#    'version': '3'},
#   'id': '55967741',
#   'pos': [38.1595149, -122.4967254],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:17:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55967915',
#   'pos': [38.512434, -123.069322],
#   'type': 'node'},
#  {'created': {'changeset': '27434565',
#    'timestamp': '2014-12-13T03:23:39Z',
#    'uid': '86565',
#    'user': 'ricomundy',
#    'version': '4'},
#   'id': '55968045',
#   'pos': [38.6943311, -123.4225143],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T14:00:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55968189',
#   'pos': [38.3591657, -122.2636311],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:17:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55968347',
#   'pos': [38.181565, -122.450961],
#   'type': 'node'},
#  {'created': {'changeset': '7927121',
#    'timestamp': '2011-04-21T16:50:27Z',
#    'uid': '74275',
#    'user': 'behemoth14',
#    'version': '5'},
#   'id': '55968478',
#   'pos': [38.1924488, -122.2593701],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:17:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55968618',
#   'pos': [38.397478, -123.019195],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:20:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '55968998',
#   'pos': [38.4742312, -122.6799034],
#   'type': 'node'},
#  {'created': {'changeset': '3346372',
#    'timestamp': '2009-12-11T02:56:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55969247',
#   'pos': [38.4693803, -122.7529968],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:17:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55969389',
#   'pos': [38.60758, -123.258631],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:17:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55969565',
#   'pos': [38.459733, -123.000131],
#   'type': 'node'},
#  {'created': {'changeset': '27104286',
#    'timestamp': '2014-11-29T04:00:29Z',
#    'uid': '86565',
#    'user': 'ricomundy',
#    'version': '4'},
#   'id': '55969709',
#   'pos': [38.291466, -122.398761],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:18:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55969873',
#   'pos': [38.2721659, -122.6740387],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T14:01:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55970050',
#   'pos': [38.5673983, -122.4573331],
#   'type': 'node'},
#  {'created': {'changeset': '18274602',
#    'timestamp': '2013-10-10T03:38:05Z',
#    'uid': '371121',
#    'user': 'AndrewSnow',
#    'version': '3'},
#   'id': '55970227',
#   'pos': [38.3161883, -122.3432845],
#   'type': 'node'},
#  {'created': {'changeset': '27296842',
#    'timestamp': '2014-12-06T18:59:26Z',
#    'uid': '115918',
#    'user': 'Timothy Smith',
#    'version': '3'},
#   'id': '55970405',
#   'pos': [38.3133445, -122.7000073],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:18:35Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55970549',
#   'pos': [38.654799, -123.281883],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:20:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55970661',
#   'pos': [38.703403, -123.288089],
#   'type': 'node'},
#  {'created': {'changeset': '18344361',
#    'timestamp': '2013-10-14T07:01:48Z',
#    'uid': '371121',
#    'user': 'AndrewSnow',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '55970839',
#   'pos': [38.3060072, -122.3174123],
#   'type': 'node'},
#  {'created': {'changeset': '18886502',
#    'timestamp': '2013-11-14T01:11:06Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '4'},
#   'highway': 'turning_circle',
#   'id': '55971016',
#   'pos': [38.1805, -122.2697167],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:20:32Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55971158',
#   'pos': [38.649404, -123.214624],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:20:32Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55971277',
#   'pos': [38.640045, -123.328678],
#   'type': 'node'},
#  {'created': {'changeset': '6521261',
#    'timestamp': '2010-12-02T23:55:23Z',
#    'uid': '14293',
#    'user': 'KindredCoda',
#    'version': '6'},
#   'id': '55971473',
#   'pos': [38.307149, -122.3055222],
#   'type': 'node'},
#  {'created': {'changeset': '18036000',
#    'timestamp': '2013-09-25T21:32:17Z',
#    'uid': '28775',
#    'user': 'StellanL',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '55971807',
#   'pos': [38.2930427, -122.3128591],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:19:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55972108',
#   'pos': [38.461352, -122.7290649],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:20:38Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55972255',
#   'pos': [38.567654, -122.872091],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:20:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55972418',
#   'pos': [38.4447075, -122.5918341],
#   'type': 'node'},
#  {'created': {'changeset': '3111818',
#    'timestamp': '2009-11-14T10:20:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55972523',
#   'pos': [38.456026, -122.588557],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:19:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55972674',
#   'pos': [38.533032, -123.116466],
#   'type': 'node'},
#  {'created': {'changeset': '27104920',
#    'timestamp': '2014-11-29T05:56:04Z',
#    'uid': '86565',
#    'user': 'ricomundy',
#    'version': '3'},
#   'id': '55972797',
#   'pos': [38.6087033, -123.0132526],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:19:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '55972910',
#   'pos': [38.58827, -123.040718],
#   'type': 'node'},
#  {'created': {'changeset': '27104920',
#    'timestamp': '2014-11-29T05:56:02Z',
#    'uid': '86565',
#    'user': 'ricomundy',
#    'version': '3'},
#   'id': '55973046',
#   'pos': [38.569123, -123.04576],
#   'type': 'node'},
#  {'created': {'changeset': '3032266',
#    'timestamp': '2009-11-04T12:20:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '4'},
#   'id': '55973167',
#   'pos': [38.3914732, -123.0861555],
#   'type': 'node'},
#  {'created': {'changeset': '21830037',
#    'timestamp': '2014-04-21T06:46:41Z',
#    'uid': '115918',
#    'user': 'Timothy Smith',
#    'version': '4'},
#   'highway': 'turning_circle',
#   'id': '55973448',
#   'pos': [38.3467802, -122.3153134],
#   'type': 'node'},
#  {'created': {'changeset': '3113243',
#    'timestamp': '2009-11-14T14:03:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '55973614',
#   'pos': [38.2268422, -122.3075215],
#   'type': 'node'},
#  ...]
